# %% [markdown]
# # Hashtag Analysis
#
# #### Importing useful libraries

# %%
# Import libraries
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Out:
# /var/folders/j_/9989vv3d7z7c61s49rkzydxm0000gn/T/ipykernel_88167/3164883191.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Replace file path with the personal one in which the dataset is contained
chunk = pd.read_csv("/Users/eliacannas/Desktop/SentimentAnalysis/venv/tweets_sentimentAnalysis.csv", chunksize=100000,lineterminator='\n', low_memory=False)
dfSent = pd.concat(chunk)
dfSent.info()
dfSent.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2689765 entries, 0 to 2689764
# Data columns (total 15 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_name         object
#  1   user_location     object
#  2   user_description  object
#  3   user_created      object
#  4   user_followers    int64
#  5   user_friends      int64
#  6   user_favourites   int64
#  7   user_verified     bool
#  8   date              object
#  9   text              object
#  10  hashtags          object
#  11  source            object
#        object t
#  13  polarity          float64
#  14  subjectivity      float64
# dtypes: bool(1), float64(2), int64(3), object(9)
# memory usage: 289.9+ MB
#                 user_name    user_location  \
# 0             NFT Nomad 💎              NaN
# 1  Digital Shogun ပωပ 🛡🌐⚔  Rings of Saturn
# 2              Conor Okus          Global
# 3              Kyptos.com              NaN
# 4        Dr. Crypto Jones      Atlanta, GA
#
#                                     user_description         user_created  \
# 0              NFT Creator:\nhttps://t.co/gz5OlavMCa  2021-11-24 07:08:31
# 1  Non-Binary🏳️‍🌈Metaverse Builder. Web3 Content ...  2021-01-19 10:54:08
# 2  Making #Bitcoin more than an investment @spira...  2012-01-16 20:55:11
# 3  https://t.co/d03RricqLo - Latest News About Cr...  2021-09-20 02:40:53
# 4  I am NOT a financial advisor. I AM a cryptocur...  2021-03-21 01:27:11
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0              65            64              111          False
# 1            4082           221            59613          False
# 2            3771           439            11363          False
# 3           10330           217               36          False
# 4              19           109              132          False
#
#                   date                                               text  \
# 0  2022-01-11 17:11:49  $ LNR going huge ! ! ! ! Kucoin bitmart listin...
# 1  2022-01-11 17:11:49  Another decent bounce # Bitcoin $ BTC 1w , 1d ...
# 2  2022-01-11 17:11:49  Heads ! I 'll going live Thursday 18:30 UTC @ ...
# 3  2022-01-11 17:11:50  Will LUNA Price Bounce Again .382 Fibonacci Re...
# 4  2022-01-11 17:11:51  Not much , 2022 good baby ! Bing bong ! # NFT ...
#
#                                             hashtags               source  \
# 0  ['Ethereum', 'crypto', 'cryptocurrency', 'nft'...  Twitter for Android
# 1                                ['Bitcoin', 'HODL']  Twitter for Android
# 2                                        ['Bitcoin']      Twitter Web App
# 3  ['bitcoin', 'ElSalvador', 'metaverse', 'NFTs',...                IFTTT
# 4                     ['NFT', 'Ethereum', 'Bitcoin']  Twitter for Android
#
#   is_retweet\r  polarity  subjectivity
# 0      False\r  0.550000      0.650000
# 1      False\r  0.222222      0.518519
# 2      False\r  0.568182      0.400000
# 3      False\r  0.000000      0.000000
# 4      False\r  0.450000      0.400000

# %% [markdown]
# #### Correcting column types

# %%
# Conversion of column types
dfSent = dfSent.convert_dtypes()
dfSent.dtypes
# Out:
# user_name           string[python]
# user_location       string[python]
# user_description    string[python]
# user_created        string[python]
# user_followers               Int64
# user_friends                 Int64
# user_favourites              Int64
# user_verified              boolean
# date                string[python]
# text                string[python]
# hashtags            string[python]
# source              string[python]
# is_retweet\r        string[python]
# polarity                   Float64
# subjectivity               Float64
# dtype: object

# %% [markdown]
# #### Sentiment column creation based on polarity

# %%
# Assigning positive, negative or neutral value based on polarity, creating new column in dataset 'Sentiment' and removing unnecessary columns
df_sentiment = dfSent.copy()
df_sentiment['Sentiment'] = df_sentiment["polarity"].apply(lambda x: "Positive" if x > 0 else( "Negative" if x < 0  else "Neutral"))
df_sentiment.drop(['user_description','user_created','source','subjectivity'],axis=1,inplace=True)
df_sentiment.head()
# Out:
#                 user_name    user_location  user_followers  user_friends  \
# 0             NFT Nomad 💎             <NA>              65            64
# 1  Digital Shogun ပωပ 🛡🌐⚔  Rings of Saturn            4082           221
# 2              Conor Okus          Global             3771           439
# 3              Kyptos.com             <NA>           10330           217
# 4        Dr. Crypto Jones      Atlanta, GA              19           109
#
#    user_favourites  user_verified                 date  \
# 0              111          False  2022-01-11 17:11:49
# 1            59613          False  2022-01-11 17:11:49
# 2            11363          False  2022-01-11 17:11:49
# 3               36          False  2022-01-11 17:11:50
# 4              132          False  2022-01-11 17:11:51
#
#                                                 text  \
# 0  $ LNR going huge ! ! ! ! Kucoin bitmart listin...
# 1  Another decent bounce # Bitcoin $ BTC 1w , 1d ...
# 2  Heads ! I 'll going live Thursday 18:30 UTC @ ...
# 3  Will LUNA Price Bounce Again .382 Fibonacci Re...
# 4  Not much , 2022 good baby ! Bing bong ! # NFT ...
#
#                                             hashtags is_retweet\r  polarity  \
# 0  ['Ethereum', 'crypto', 'cryptocurrency', 'nft'...       False
#       0.55
# 1                                ['Bitcoin', 'HODL']       False
#   0.222222
# 2                                        ['Bitcoin']       False
#   0.568182
# 3  ['bitcoin', 'ElSalvador', 'metaverse', 'NFTs',...       False
#        0.0
# 4                     ['NFT', 'Ethereum', 'Bitcoin']       False
#       0.45
#
#   Sentiment
# 0  Positive
# 1  Positive
# 2  Positive
# 3   Neutral
# 4  Positive

# %%
# String formatting
df_sentiment['date'] = pd.to_datetime(df_sentiment['date'], format='%Y-%m-%d %H:%M:%S').dt.date

# %% [markdown]
# #### Filtering study period bitcoin trend

# %%
# Filter the DataFrame for dates between March and June 2022
start_date = pd.to_datetime('2022-03-01').date()
end_date = pd.to_datetime('2022-06-30').date()
df_sentiment = df_sentiment.loc[(df_sentiment['date'] >= start_date) & (df_sentiment['date'] <= end_date)].reset_index(drop=True)

# %% [markdown]
# #### Search for most influential hashtags

# %%
def hashtagInfluent_general(df):
    # Create a list of all hashtags
    all_hashtags = [] # List
    for hashtags_str in df['hashtags']:
        # Remove unwanted characters and split to get list of hashtags
        hashtags = [tag.strip("[]'") for tag in hashtags_str.split(', ')]
        all_hashtags.extend(hashtags)
    
    # Remove any special characters from the hashtags
    all_hashtags = [tag.strip("#") for tag in all_hashtags]
    
    # Count the frequency of hashtags
    hashtags_frequency = pd.Series(all_hashtags).value_counts()
    
    # View the N most influential hashtags (change N to your choice)
    number_hashtags_influent = 51
    hashtags_influent = hashtags_frequency.head(number_hashtags_influent)
    
    # Get an array of the 50 most influential hashtags
    array_hashtags_influent = hashtags_influent.index.tolist()
    
    # Print the most influential hashtags
    print("The most influential hashtags in the dataset:")
    print(array_hashtags_influent)
    return array_hashtags_influent

# %%
df_sentiment['hashtags'] = df_sentiment['hashtags'].astype(str)
array = hashtagInfluent_general(df_sentiment) # Save result in array for use next
# Out:
# The most influential hashtags in the dataset:
# ['BTC', 'Bitcoin', 'bitcoin', 'btc', 'ETH', 'cryptocurrency', 'crypto', 'Crypto', 'NFT', 'Ethereum', 'BNB', 'eth', 'Binance', 'blockchain', 'BSC', 'NFTs', 'DeFi', 'Metaverse', 'nft', 'NFTCommunity', 'ethereum', 'binance', 'Airdrop', 'altcoin', 'ADA', 'SHIB', 'trading', 'nftart', 'Solana', 'LightningNetwork', 'BITCOIN', 'LN', 'boltcoiner', 'CryptoMining', 'CryptoNews', 'XRP', 'USDT', 'Web3', 'Cryptocurrency', 'SeasonalTokens', 'bnb', 'cryptotrading', 'cryptonews', 'cryptocurrencies', 'DOGE', 'coinhuntworld', 'SOL', 'dogecoin', 'AVAX', 'whale', 'money']

# %% [markdown]
# #### Hashtags and tweet for the period of interest

# %%
# Function to find the most influential hashtags in a given period
def hashtagInfluent_period(df):
    # Create a list of all unique hashtags in the period of interest
    all_hashtags = []
    for hashtags_str in filtered_df['hashtags']:
        # Remove unwanted characters and split to get list of hashtags
        hashtags = [tag.strip("[]'") for tag in hashtags_str.split(', ')]
        all_hashtags.extend(hashtags)
    
    # Remove any special characters from the hashtags
    all_hashtags = [tag.strip("#") for tag in all_hashtags]
    
    # Count the frequency of unique hashtags
    hashtags_frequency = pd.Series(all_hashtags).value_counts()
    
    # Specifies the number of most influential hashtags to include
    number_hashtags_influent = 150
    
    # Get the n most influential hashtags
    hashtags_influent = hashtags_frequency.head(number_hashtags_influent).index.tolist()
    
    # Remove hashtags from the list hashtags_influent_first
    for hashtag in array:
        if hashtag in hashtags_influent:
            hashtags_influent.remove(hashtag)
    
    # Print the n most influential hashtags
    print(f"The {number_hashtags_influent} most influential hashtags in the period of interest:")
    print(hashtags_influent)

# %%
# Function to print tweets with certain hashtags
def see_tweet_on_hashtag(df, list_hashtag):
    for hashtag in list_hashtag:
        # Filters the DataFrame for tweets with the specified hashtag and negative sentiment
        tweets_hashtags_negative = df[
            (df['hashtags'].apply(lambda x: hashtag in x)) & 
            (df['Sentiment'] == 'Negative')
        ]

         # Displays the tweet count for the current hashtag
        num_tweets = len(tweets_hashtags_negative)
        print(f"Hashtag: {hashtag}")
        print(f"Number of associated tweets: {num_tweets}\n")
        
        # View the text of tweets for the current hashtag
        print(f"Hashtag: {hashtag}\n")
        for index, tweet in tweets_hashtags_negative.iterrows():
            print(f"Tweet ID: {index}")
            print(f"Text: {tweet['text']}")
            print("\n")
        print("="*50 + "\n")  # Add a dividing line between hashtags

# %% [markdown]
# #### Hashtag and tweets first period

# %%
# Select the time window of the first period
start_date = pd.to_datetime('2022-05-11').date()
end_date = pd.to_datetime('2022-05-14').date()

# Filters the DataFrame for the specified dates
filtered_df = df_sentiment[(df_sentiment['date'] >= start_date) & (df_sentiment['date'] <= end_date) & (
            df_sentiment['Sentiment'] == 'Negative')]

# Control column type hashtag
filtered_df['hashtags'] = filtered_df['hashtags'].astype(str)
# Out:
# /var/folders/j_/9989vv3d7z7c61s49rkzydxm0000gn/T/ipykernel_88167/1368230139.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['hashtags'] = filtered_df['hashtags'].astype(str)

# %% [markdown]
# #### Most influential hashtags

# %%
# Call the function for print influent hashtag
hashtagInfluent_period(filtered_df)
# Out:
# The 150 most influential hashtags in the period of interest:
# ['Cryptocrash', 'LUNA', 'BitcoinCrash', 'terraluna', 'UST', 'luna', 'DCA', 'Luna', 'TradingSignals', 'Terra', 'Lunacrash', 'HODL', 'Blockchain', 'lunacoin', 'altcoins', 'doge', 'nfts', 'Coinbase', 'news', 'Tether', 'Altcoins', 'Cardano', 'cryptocrash', 'LUNAtics', 'NFA', 'Tesla', 'investing', 'buythedip', 'CryptocurrencyNews', 'bearmarket', 'TerraUSD', 'gold', 'ust', 'coinbase', 'ElonMusk', 'metaverse', 'RsiBitcoin', 'xrp', 'cryptocurrecy', 'LUNAUSDT', 'memecoin', 'SavageBeauty', 'INHLOSO', 'web3', 'elon', 'bitcoinnews', 'Cryptos', 'nftcollector', 'sanji', 'bscgem', 'sanjiinu', 'opensea', 'P2E', 'solana', 'stockmarketcrash', 'cryptogems', 'token', 'bscgemalert', 'stocks', 'next100xgem', 'Bscgems', 'nftcommunity', 'terra', 'shiba', 'art', 'defi', 'StockMarket', 'investment', 'markets', 'PancakeSwap', 'finance', 'inflation', 'Bitcoin2022', 'business', 'Gold', 'FGW', 'FunnyGameWorld', 'BTCUSD', 'Bollinger', 'RSİ', 'forex', 'Dogecoin', 'ElSalvador', 'shib', 'Russia', 'coinsbit', 'Twitter', 'fintech', 'Bullish', 'CRO', 'Ukraine', 'Stocks', 'SEC', 'bounty', 'Bsc', 'coin', 'CRYPTO', 'LTDWSOMIZI', 'GomoraMzansi', 'NFTdrop', 'Cryptocurrencies', 'LunarCrush', 'cryptoart', 'india', 'ada', 'APE']

# %% [markdown]
# #### Tweets containing the hashtags

# %%
# List of hashtags of interest
list_hashtag_interest = ['bearmarket', 'stockmarketcrash', 'Bollinger']

# %%
# Call the function with the list of hashtags
see_tweet_on_hashtag(filtered_df, list_hashtag_interest)
# Out:
# Hashtag: bearmarket
# Number of associated tweets: 70
#
# Hashtag: bearmarket
#
# Tweet ID: 875711
# Text: You know # crypto markets fucked 's core coins green # stablecoins # luna # Cryptocrash # cryptocurrencies # buythedip # bearmarket # Bitcoin # BitcoinCrash https : //t.co/q4QxE3XenM
#
#
# Tweet ID: 879391
# Text: Time accept sad truth `` Bear Market '' ! # Bitcoin # bearmarket # cryptocurrency
#
#
# Tweet ID: 880940
# Text: I got heart attack looking portfolio . -25 % past 24 hours , I 50 % loss , general , That 's ... scary lot ? How guys living life # bearmarket ? 😢 # buythedip # bitcoin
#
#
# Tweet ID: 881844
# Text: The market bad . Are buying dip ? # stockmarketcrash # StockMarket # Cryptocrash # cryptotrading # BTC # BitcoinCrash # Bitcoin # Ethereum # ETH # ETHNFTs # NFTs # buythedip # HODL # APE # SOL # Solana # fintech # news # bearmarket # AMC # GME https : //t.co/mF4LO5Wq6E
#
#
# Tweet ID: 882324
# Text: Do n't Worry The Only Chart Matter This One Bitcoin Will Always Be The Winner In Long Term # cryptotrading # cryptocurrencies # bearmarket # bitcoin https : //t.co/4JVSAdATGY
#
#
# Tweet ID: 882559
# Text: How long # longterm ? # Cryptos # Altcoins # bitcoin # stocks # Crypto # buythedip # HODL # HODLers # HODLing # bearmarket https : //t.co/LBQw3SSHq0
#
#
# Tweet ID: 885289
# Text: How navigate # Cryptocrash / # stockmarketcrash ? My thoughts video coming next half hour ! # bitcoin # Ethereum # eth # btc # Crypto # cryptocurrecy # bearmarket @ saylor @ elonmusk # marketcrash
#
#
# Tweet ID: 886227
# Text: Chill bottom 1k less cares . Up . Everyone panic mode IS bottom . # uponly # Bitcoin # bearmarket
#
#
# Tweet ID: 886459
# Text: Do n't shocked see Crypto mentor completing task join discord whitelist .. 😢 E red man😂 # terraluna # Bitcoin # bearmarket
#
#
# Tweet ID: 889353
# Text: Bargain prices . Going shopping 🛍 😁 NFA . Be greedy others fearful . # BlackCrypto # bearmarket # onsale # Giveaways # millionaire # Bitcoin # Eth $ skey $ LPT https : //t.co/8RXhd6SGC1
#
#
# Tweet ID: 890805
# Text: I saved ~ $ 30k buy dip , BUT NOW ’ dipping . Wtf I ? # Coinbase # Bitcoin # bearmarket # crypto
#
#
# Tweet ID: 891364
# Text: I reckon nuke 21K @ Solokov_Sats green line 67K 😤 # bitcoin # bearmarket # Cryptocrash https : //t.co/l63wTHkI57
#
#
# Tweet ID: 891894
# Text: Whoever buying shitcoins today Bitcoin matter mentally challenged . # Bitcoin # bearmarket # shitcoins
#
#
# Tweet ID: 892775
# Text: BITCOIN Maxi , @ saylor & amp ; @ terra_money please save pet otherwise 's gon na unleash hell financial market . If today price fail climb 29000USD & amp ; break 32000USD , believe , see biggest financial melt history🥶 # Bitcoin # BTC # bearmarket # LUNA https : //t.co/lyuyt5nbsd
#
#
# Tweet ID: 896497
# Text: What I learned # bearmarket people ’ know shit ! Bankers control . # Bitcoin
#
#
# Tweet ID: 900116
# Text: Sad truth Joke Day ! Stay positive Hold everyone ! # cryptocurrency # terraluna # luna # TerraUSD # LUNAUSDT # cryptotrading # bearmarket # Truth # CoinMarketCap # Bitcoin # ETH # KuCoin # Binance # Coinbase # HODL https : //t.co/wE8SpWBMs8
#
#
# Tweet ID: 901670
# Text: Can someone wake # SatoshiNakamoto jerk offs half ass business degrees Jeffrey Epstein university destroying crypto markets . # Bitcoin # BTC # Cryptocrash # cryptocurrency # bearmarket # CitadelScandal # Citadel # BlackRock https : //t.co/woMR6Bww8l
#
#
# Tweet ID: 901785
# Text: I dreamed end ... But I woke worse 😱 # cryto # bearmarket # Bitcoin # Ethereum # crytomonnaies https : //t.co/nLOkj9O5ml
#
#
# Tweet ID: 901885
# Text: Never much fun # bearmarket 🤣😆 big moves day long , I feel # Bitcoin , sad see profits wiped away days 🙈 # Crypto # cryptotrading
#
#
# Tweet ID: 901973
# Text: $ 65k ATH * 85 % dip = ~ $ 10k ATL $ BTC # Bitcoin $ 5k ATH * 90 % dip = ~ $ 500 ATL $ ETH # Ethereum $ 80 ATH * 95 % dip = ~ $ 4 ATL $ ENS …I bet makes feel sad . # Cryptotwitter # bearmarket
#
#
# Tweet ID: 902423
# Text: Lets burn everything ashes rebuild ! I 'm numb lowkey enjoying # ct # bearmarket # bitcoin # buythedip # buythedipx10
#
#
# Tweet ID: 903135
# Text: # bearmarket arrived It 's time learn wrong regrets . It 's time think succeed next bull run . # Bitcoin # Crypto # Cryptocrash # BitcoinCrash https : //t.co/Td8IeybtRb
#
#
# Tweet ID: 903841
# Text: # Bitcoin 15 % past 24 hours coming past 10 hours ! # BTC # bloodbath # crash # bearmarket https : //t.co/3N5xWAbtio
#
#
# Tweet ID: 904037
# Text: My whacky crypto predictions . 1 ) Microstrategy BTC resolve tested soon 2 ) Novagratz probably sold/hedged Luna got tattoo 3 ) All VCs hedged crypto long time ago FTX/Binance # Bitcoin # LUNA # ust # eth # bearmarket # Cryptocrash
#
#
# Tweet ID: 904680
# Text: # USDT Losing ’ PEG aswell . Blood spilled ! This bad future regulations # stablecoins . # Bitcoin # cryptotrading # bearmarket
#
#
# Tweet ID: 906501
# Text: Chairmen SEC CFTC talk crypto regulation ISDA meeting : https : //t.co/8G6vUQu8E1 # topcryptonews # cryptonews # regulation # isda # CFTC # fxt # crypto # Bitcoin # Ethereum # bearmarket https : //t.co/Uv2AxXbRu9
#
#
# Tweet ID: 907521
# Text: 12 Angry Man | 10 @ opensea # OpenSeaNFT # openseanftart # NFTs # NFT # nftart # NFTCommunity # NFTartists # NFTProjects # Bitcoin # bearmarket # altcoinseason # Bitcoin # Tether # SHIB # SHAK https : //t.co/pL9cR8rCJ6
#
#
# Tweet ID: 909231
# Text: Number days took us reach 200WMA # bearmarket , ATH : - 2014 : 630 days - 2018 : 364 days With today 's wick , 're 15 % away MA , spent ~182 days downtrend 📉 💨 # Bitcoin $ BTC
#
#
# Tweet ID: 910223
# Text: 15N game 1 ETH prize . Call friends , buy cards increase chance . @ opensea # OpenSeaNFT # openseanftart # NFTs # NFT # nftart # NFTCommunity # NFTartists # NFTProjects # Bitcoin # bearmarket # altcoin # Currencycom # BitcoinCrash # 1000xgem https : //t.co/3Z39vu8s0e
#
#
# Tweet ID: 910693
# Text: All peoples # blockchain understand , What shit ! ! ! Only one sentence : # bearmarket fucked us ... # Avalanche # BTC # LUNA # Bitcoin # ETH # USDT # BSC # BNB https : //t.co/ngs036yIIc
#
#
# Tweet ID: 911813
# Text: Back financial freedom hard work sers . # Bitcoin # bearmarket # WorkLifeBalance https : //t.co/Si2xd0280N
#
#
# Tweet ID: 912535
# Text: YouYour portfolio might red people throwing words like # cryptocrash , # lunarcrush # bearmarket around . No matter bad gets , take step back . If losing thinking hurting reach friends family . # luna # Bitcoin
#
#
# Tweet ID: 915297
# Text: Still n't understand $ trx green 💚 # BitcoinCrash # Bitcoin # bearmarket https : //t.co/zsB8eXBbeD
#
#
# Tweet ID: 915973
# Text: $ BTC still 2017 peak… definitely bear market next halving 2024 . NOW time making money investing… least ’ I would money coming right now… 🤦‍♂️ # bitcoin # btc # crypto # ethereum # bearmarket # 2017peak https : //t.co/HznCQjeeHU
#
#
# Tweet ID: 916026
# Text: close # bearmarket https : //t.co/7nnfrBrDDl waiting long time . Dont afraid bear market easyest way make money # bitcoin # ETH # tether # cryptocrash # cryptotrading
#
#
# Tweet ID: 919297
# Text: Two tips develop strategy consider worst scenario ( liquidity ) divide well portfolio investement-cash # cryptotrading # bitcoin # Ethereum # ETH # sp500 # spx # bearmarket
#
#
# Tweet ID: 919585
# Text: Other thing , must study think retail thing instutional ... must know thinking proffessionals . # btc # bitcoin # Ethereum # eth # sp500 # spx # bearmarket
#
#
# Tweet ID: 920268
# Text: You ’ make shit # safemoon middle # bearmarket 30 % whilst # Bitcoin # Ethereum 20 % … ? Only # SAFEMOONARMY 🔥🔥🔥🎉💯🙏🏾✅ https : //t.co/t8M5mTrznC
#
#
# Tweet ID: 921832
# Text: Dear @ SingaporePolice please arrest @ stablekwon ? $ LUNA 📉🩸 # Terra # luna # terraluna # ust # altcoins # bitcoin # bearmarket # Lunacrash # BitcoinCrash https : //t.co/k5vH0O8mAN
#
#
# Tweet ID: 922441
# Text: Do n't get fixated $ LUNA , $ UST , $ USDT . Market 's bouncing ready leave behind '' always '' # Bitcoin # Altcoins # bearmarket # cryptocrash
#
#
# Tweet ID: 922918
# Text: I want see bitcoin dominance 54 % - many shitcoins market . Flush crap peak fear accumulation period . That future millionaires made # Bitcoin # bearmarket $ btc
#
#
# Tweet ID: 924430
# Text: Last July big HSBAF began @ elonmusk saying ' I may pump , I n't dump ' . But # HSBAF n't need catalyst . This time come nowhere , bringing destruction painted green dildo doorway . # BitcoinCrash # bearmarket # Bitcoin
#
#
# Tweet ID: 927417
# Text: The big blue line $ 30k . It flipped “ support ” “ resistance ” . Not great BTC . # BTC # BitcoinCrash # bearmarket # XRP # BITCOIN # Bitcoin2022 # btc # ETH # EthereumNFTs # eth # Crypto # Cryptocrash # cryptocurrency # cryptocurrencies https : //t.co/BSgbN4sHwe
#
#
# Tweet ID: 930318
# Text: Go away stupid # Bear ! ! No one wants ! ! 😂😂 # Bitcoin # BitcoinCrash # Lunacrash # bearmarket # BTC # ETH literally time see project survive ! After lot gone ! Along stupid # Bear 😂😂😂 🐻🐻🔫🔫 https : //t.co/0Yp4pO4Y6h
#
#
# Tweet ID: 930408
# Text: Guys careful 😞 opinion # bitcoin Could n't reach # 30k 😞 I think ca n't see price # 30k long time # bearmarket # HODL # BTC Not financial advice https : //t.co/dGjVLnZHAO
#
#
# Tweet ID: 931923
# Text: Big everyone buying dips .. ya ’ better Macdonalds grab 20 chicken nugget box put dips use 😂🤣 # PPMWAY # BTC # Binance # futures # crypto # cryptocurrency # bearmarket # Bitcoin # BTCUSD # Signals # cryptosignal # BYBIT
#
#
# Tweet ID: 932973
# Text: # Bitcoin cleared liquidity lows . See sellers getting exhausted By @ CryptoMichNL 👇 # MoneyInTheRightDirection # BuyTheDip # NotPanicSell # bearmarket @ CorionPlatform https : //t.co/Tbu4KBQSex
#
#
# Tweet ID: 934574
# Text: Visual representation crypto market past couple days # cryptocrash # ethereum # bitcoin # crypto # nft # nftcommunity # bearmarket https : //t.co/5NA3xxAoR3
#
#
# Tweet ID: 935839
# Text: Buying $ LUNA $ 0.0014 ’ sound bad anymore # Crypto # Bitcoin # Ethereum # Metaverse # bearmarket # BullMarket https : //t.co/dUDPIasdkF
#
#
# Tweet ID: 937032
# Text: This # Crypto Bull cycle little disappointing I would say . # cryptocurrecy # Bitcoin # bearmarket
#
#
# Tweet ID: 937254
# Text: Is Luna going recover ? What think ? # LUNA # dead # project # nft # family # collector # CRO # bitcoin # ethereum # bearmarket # holdon # terraluna # TerraUSD # believe # BitcoinCrash # USDT
#
#
# Tweet ID: 937420
# Text: The last time # Bitcoin retested 140w MA , bounced hard ! Will ? 🧐👇 $ btc # Bitcoin # BTC # bearmarket # BitcoinCrash https : //t.co/YZ1RdEiPAG
#
#
# Tweet ID: 940008
# Text: It times like transfer money happens impatient patient . # Solana # Ethereum # Bitcoin # LUNA # NFTs # NFTGiveaways # bearmarket
#
#
# Tweet ID: 940442
# Text: While crypto acting like Bit…… I chilling daughters ice cream shop @ TepoznievesMx near # originapedregal # MexicoCity # Crypto # cryptocrash # bearmarket # Lunacrash # Coinbase # Bitcoin # cryptofamily # icecream # lifeisgood https : //t.co/ccj6jwqM1H
#
#
# Tweet ID: 941163
# Text: There market confidence $ btc finally tests 200 week moving average . Careful false 30k breakout . # bearmarket # Bitcoin # daytrading
#
#
# Tweet ID: 945395
# Text: WE HAVE LIFTOFF ! ! BULL MARKET INCOMING ! BITCOIN , ETHEREUM , XRP CRYPTO IS ON THE MOVE UP ! PLEASE BE CAREFUL INVESTING IN THESE CONDITIONS ! 👉🏽https : //t.co/PEgMf2EmMg👈🏽 # BullMarket # bearmarket # Cryptocrash # cryptocurrency # cro # Bitcoin # Ethereum # Crypto https : //t.co/L3SkhW1czg
#
#
# Tweet ID: 945901
# Text: Ignore noise Ignore people saying twitter/Telegram , keep focus bluechip projects long term vision survive crypto market make . # Bitcoin # IgnoreNoise # bearmarket /07
#
#
# Tweet ID: 946530
# Text: gm . longer stay bed , less money spend . # bearmarket # Cryptocrash # Bitcoin # ETH # BTC # PJPP # BAYC
#
#
# Tweet ID: 951243
# Text: 12 Angry Man | # 8 @ opensea # OpenSeaNFT # openseanftart # NFTs # NFT # nftart # NFTCommunity # NFTartists # NFTProjects # Bitcoin # bearmarket # altcoinseason # Bitcoin # Tether # SHIB # ShakeIt https : //t.co/7pb0BcGDaZ
#
#
# Tweet ID: 952395
# Text: Damn I sold everything yesterday bounces ... I 'm weak # crypto # cryptocrash # bounce # bearmarketrally # BTC # Bitcoin # Solana # Sol # Ethereum # ETH # Terraluna # lunacoin
#
#
# Tweet ID: 953018
# Text: DAY 1 : markets FRIDAY THE 13TH ! ! ? ! Ahhhh I degen shit I going get rekt today days… # degendiary # Ethereum # solana # Crypto # NFTCommunity # NFTProject # SolanaNFT # EthereumNFTs # bitcoin # Cryptocrash # BTC # bearmarket # CryptocurrencyNews
#
#
# Tweet ID: 960528
# Text: Massive levels $ BTC . Watching 32,500-34,500 $ hold close week short term reversal signal . Below 27-28k ranges things could get ugly . # daytrading # SPX # DXY # Bitcoin # bearmarket # BTC https : //t.co/UtdBmu7F5s
#
#
# Tweet ID: 967268
# Text: Crazy bear market , although costly make next generation millionaires wealth acquisition . Can wait see monsters come . # Cryptocrash # cryptocurrency # bearmarket # Crypto # BTC
#
#
# Tweet ID: 967648
# Text: In # bearmarket ’ tough keep # DCAing losses . As I mention months ago . I going keep DCA slowly . Once month smaller budget . Building bags # ApeCoin , # ADA # BTC # ETH # Matic # Cake # AVAX # PlayToEarn games https : //t.co/Ov0gwyu4IJ
#
#
# Tweet ID: 968649
# Text: The # bearmarket lasts long ... # buythedip # bullmarket # bitcoin https : //t.co/AdgGXsAA9C
#
#
# Tweet ID: 969553
# Text: Sorry I wo n't bail hyped people bought # Bitcoin 's mini pump peak money . Waiting deeper correction ( crash ) 😎 Not financial advice .... # btc # Cryptocrash # Cryptos # cryptocurrency # bearmarket https : //t.co/6loLNr8znf
#
#
# Tweet ID: 970999
# Text: $ BTC Fake sideways , confirmation dip losing resistance . Don ’ fooled RSI , use everything . This 3 days yet . # BTC # bearmarket # StockMarket ps I ’ financial advisor , I smarter . https : //t.co/XzV19ogdjE
#
#
# Tweet ID: 974138
# Text: Make money # crypto # bearmarket # BullMarket ! Our custom made trading bot making crazy profits ! 🤖💵🤖🚀 Join discord info upcoming beta launch : https : //t.co/gCed7eTkwC # Bitcoin # cryptotrading # cryptocurrency # trading $ luna $ eth https : //t.co/ke1LzqBAGx
#
#
# Tweet ID: 979043
# Text: I ’ remembering buying Summer 21 ’ thinking , ‘ What lifetime opportunity ’ . Now I look range like pathetic slut say , ‘ Only plebs buy # Bitcoin ’ . # bearmarket https : //t.co/5d2XZIChj5
#
#
# Tweet ID: 979581
# Text: Luna went zero . Is ? # LUNA # dead # project # nft # family # collector # CRO # bitcoin # ethereum # bearmarket # holdon # terraluna # TerraUSD # believe # BitcoinCrash # USDT
#
#
# ==================================================
#
# Hashtag: stockmarketcrash
# Number of associated tweets: 45
#
# Hashtag: stockmarketcrash
#
# Tweet ID: 874551
# Text: Ive lost much money past two years think ive become desensitized . Wake everyday , lose another 10-20 % . Still buyin dip tho😉 # Bitcoin # stockmarketcrash # buythedip
#
#
# Tweet ID: 876211
# Text: Stepn ’ ‘ Move-to-Earn ’ Model Has Crypto Analysts Seeing Value Long Run https : //t.co/MpJbFOLBWs via @ coindesk # Crypto # CryptoNews # Bitcoin # Altcoins # cryptocurrency # cryptocurrencies # fiatisdead # stockmarketcrash
#
#
# Tweet ID: 879315
# Text: `` This sucker could go '' 🤡🐻 # StockMarket # Cryptocrash # Bitcoin # LUNA # cryptotrading # Crypto # stockmarketcrash
#
#
# Tweet ID: 881844
# Text: The market bad . Are buying dip ? # stockmarketcrash # StockMarket # Cryptocrash # cryptotrading # BTC # BitcoinCrash # Bitcoin # Ethereum # ETH # ETHNFTs # NFTs # buythedip # HODL # APE # SOL # Solana # fintech # news # bearmarket # AMC # GME https : //t.co/mF4LO5Wq6E
#
#
# Tweet ID: 882237
# Text: This four year cycle 📈📈📉 If frustrated right - n't worry ! The halving coming ! Wanting learn invest ? Follow trading investing tips ! Let 's start journey together . # stockmarketcrash # bitcoin # Crypto
#
#
# Tweet ID: 882687
# Text: Wow news bad sheesh I tried warn people head fakes https : //t.co/NPJvERmmqj $ amc $ gme $ upst $ nvda $ amzn $ tsla $ msft $ goog $ ater $ rdbx $ bbig $ HD $ gs $ u $ rblx $ arkk # stocks # stockmarketcrash # StockMarket # bitcoin # LunarCrush @ jimcramer @ MadMoneyOnCNBC @ ryancohen
#
#
# Tweet ID: 883407
# Text: I ’ need sex , markets fuck everyday . # Bitcoin # stockmarketcrash # Cryptocrash
#
#
# Tweet ID: 884836
# Text: How ’ difficult understand prices super low , ’ buy A LOT afford . It ’ simple trade philosophy . # Crypto # buythedip # stockmarketcrash # Bitcoin # LUNAUSDT # cryptotrading
#
#
# Tweet ID: 885289
# Text: How navigate # Cryptocrash / # stockmarketcrash ? My thoughts video coming next half hour ! # bitcoin # Ethereum # eth # btc # Crypto # cryptocurrecy # bearmarket @ saylor @ elonmusk # marketcrash
#
#
# Tweet ID: 888533
# Text: Are market crashing Government highest paid scholars knows unfortunately fail common sense ! For interest ! Prove wrong ! # Failed # Stock Market # stockmarketcrash # dogecoin # shiba # Bitcoin # SHINJA # cryptocurrencies
#
#
# Tweet ID: 892681
# Text: Don ’ even wan na see prices morning # Bitcoin # DoKwon # cpi # stockmarketcrash
#
#
# Tweet ID: 897988
# Text: The fastest way get inflation right front @ federalreserve . Just ban crypto converted USD . That evaporate trillion $ economy without hurting poor . # inflation # Fed # FederalReserve # Bitcoin # Crypto # stockmarketcrash
#
#
# Tweet ID: 898208
# Text: Considering current market conditions @ GenosERC # GENOS holding well . Cool wallet privacy tech team pull . # Bitcoin # BitcoinCrash # BitcoinButton # Bitcoin2022 # LUFFY # LUNAUSDT wtf guys # stockmarketcrash # Ethereum # BTC # cryptotrading # NFTGiveaways # UST https : //t.co/khCSyrn89o
#
#
# Tweet ID: 900085
# Text: # Avalanche 30 % , # Solana slumped 26 % , # Bitcoin tumbled 10 % less $ 30,000 Annual # inflation # rate # US slowed 8.3 % April 41-year high 8.5 % March , less market forecasts 8.1 # Cryptocrash # trading # cmt # marketfeds # stockmarketcrash https : //t.co/knA9YdvMIY
#
#
# Tweet ID: 901680
# Text: Consoling hard times 💔💔 # Bitcoin # stockmarketcrash # Crypto # BitcoinCrash https : //t.co/Fz8xpDtQBz
#
#
# Tweet ID: 902622
# Text: The U.S. European stock markets continue falling . The first four months year worst since 1939 S & amp ; P 500 . # StockMarket # stockmarketcrash # stockmarketnews # SP500 # inflation # marketdown # derivatives # Cryptocrash # cryptocurrency # Bitcoin # ForexMarket
#
#
# Tweet ID: 902688
# Text: Guyz I find reason Behind # Cryptocrash # BitcoinCash # stockmarketcrash # Bitcoin # TerraUSD # stockmarketcrash 🤣 https : //t.co/PMxvvQcMJe
#
#
# Tweet ID: 902809
# Text: Not crypto stock way crazy going today # crypto # bitcoin # stockmarketcrash
#
#
# Tweet ID: 906269
# Text: These streets faint hearted .... # Cryptocrash # stockmarketcrash # Bitcoin https : //t.co/cOI1cXarbB
#
#
# Tweet ID: 907709
# Text: I remove facebook page red strike , limited content restriction https : //t.co/SIHRJ3C8TE https : //t.co/SIHRJ3C8TE # InternationalNursesDay # Survivor42 # cpcdebate # ไบร์ทวิน # GiveUsPeterObi # terraluna # SarkaruVaariPaata # stockmarketcrash # cryptocurrency # Cryptocrash # lufc # Bitcoin https : //t.co/PrxSaxEYCF
#
#
# Tweet ID: 908435
# Text: `` This sucker could go '' - 2008 # Cryptocrash # stockmarketcrash # stockmarkets # Bitcoin # cryptotrading # cryptocurrency # ETH # buythedip # HODL
#
#
# Tweet ID: 911070
# Text: # Bitcoin # stockmarketcrash # Lunacrash # Everyone listen anyone idea 's going market recession coming worst beginning entry year markets last 84 years inflation getting control
#
#
# Tweet ID: 911876
# Text: Don ‘ let # panic infect ! It ‘ never good advisor . Buy low sell high . Times change . # bitcoin # Cardano # Cryptocrash # Crypto # NASDAQ # stockmarketcrash
#
#
# Tweet ID: 914041
# Text: Portable naa cruise😂😂😂😂 You ca n't hate guy😂😂 # Bitcoin # Cryptocrash # terraluna # 2023Elections # stockmarketcrash # NATO # Crypto https : //t.co/8YFTs7wOh8
#
#
# Tweet ID: 917579
# Text: The # Cryptocrash avalanche intentionally created . It 's focus attention away # Crypto back USD US Digital Currency . It 's keep enslaved system , work job , stay poor . # blockchain # marketcrash # bitcoin # stockmarketcrash #
#
#
# Tweet ID: 918811
# Text: ANYONE CAN SEND ME $ 20 ? I 'M VERY BAD NOW . I WILL GO MARKET . I CAN SEND PROOF # Cryptocrash # bitcoin # luna # stockmarketcrash
#
#
# Tweet ID: 920062
# Text: Historically , crashes/downturns/recessions - whatever want call - typically created millionaires . Become financially literate . # investor # financialliteracy # mindest # longgame # buythedip # stockmarketcrash # trading # BTC # Bitcoin # ETH # SOL # LUNA
#
#
# Tweet ID: 920392
# Text: Hold tight everyone ! # stockmarketcrash # StockMarket # LUNA # Terra # Bitcoin # Bitcoin2022 https : //t.co/UsPBtbAHHP
#
#
# Tweet ID: 920846
# Text: already lot retail investors feeling earnings disappeared black hole ! 😂 '' Milky Way '' # stockmarketcrash # StockMarketindia # Nifty # sensex # Bitcoin # BlackHole # Sagittarius_A * https : //t.co/doXWXgmqum
#
#
# Tweet ID: 921293
# Text: Markets 40-70 % across board since Artificial Intelligence Bot 's sell signal & amp ; warning . I 'm genuinely trying help ... # Bitcoin # Ethereum # stockmarketcrash https : //t.co/wGEfl99ehk
#
#
# Tweet ID: 921361
# Text: tough condition csk danieal sams bumrah fire 3 # CSKvMI # Bitcoin # Cryptocrash # KenyaVsUganda # BitcoinCrash # stockmarketcrash # thursdayvibes
#
#
# Tweet ID: 921858
# Text: How I get covered financially despite fact invest fails Click retweet 🔥🔥🔥🔥🔥🔥🔥 👇🏼👇🏼👇🏼👇🏼👇🏼👇🏼👇🏼 https : //t.co/B2ursau5ez 👆👆👆👆👆👆👆👆👆 # Cryptocrash # follow # CoinMaster # Fear4TEZ # NFTCommunity # AMA # stockmarketcrash # coin # cryptocurrency # Bitcoin
#
#
# Tweet ID: 923390
# Text: @ Helloimmorgan Would put slow cooker instantaneously save market ? # journalist # chef # markets # stockmarketcrash # Cryptocrash # cryptocurrency # Crypto # Coinbase # Blockchain # meme # Memes # NoMoreRugs # DeFi # Bitcoin # ETH # Web3 # LUNA # NFTCommunity # NFT # NFTProjects https : //t.co/O01N4ScgXo
#
#
# Tweet ID: 924204
# Text: Betting digital asset ever growing digital world dumb . # Bitcoin # Cryptocrash # stockmarketcrash
#
#
# Tweet ID: 927982
# Text: After Crypto Market Crash # Cryptocrash # crypto # cryptocurrency Crypto # BitcoinCrash # stockmarketcrash # Coinbase # CryptoNews # StockMarketindia # Bitcoin # BitcoinCrash # Binance # LUNA # lunaterra # India # indian # crash # dogecoin # dogearmy # btc # cryptotrading # crying # pune # Mumbai https : //t.co/ner1h0nxT5
#
#
# Tweet ID: 931628
# Text: Nothing permanent ... Do n't stress much matter How bad situation ... It Change . # Cryptocrash # stockmarketcrash # Bitcoin
#
#
# Tweet ID: 932227
# Text: Shit might dropped like crazy weak sell . Even though im furious .. got ta remember 's temporary . # Crypto # stockmarket # Dogecoin # stockmarketcrash # bitcoin # Ethereum
#
#
# Tweet ID: 936646
# Text: How come people talking today ? This make # markets fearful . # Bitcoin # stockmarketcrash @ unusual_whales @ CryptoWhale https : //t.co/ie7nNgRtxU
#
#
# Tweet ID: 939168
# Text: I 've never seen industry provides less value society crypto . If money industry rugpulled , I n't think 'd lose anything anyone substance . # crypto # nft # Bitcoin # cryptocurrency # cryptocrash # markets # stockmarketcrash # ponzi
#
#
# Tweet ID: 943590
# Text: BREAKING : $ LUNA worth less half penny ( $ 0.002 ) # marketdump # stockmarketcrash # Bitcoin # LUNAtics # Lunacrash
#
#
# Tweet ID: 944626
# Text: Now condition stock market play x zero , money block stocks trading heavy losses I ca n't sell also . @ AshuBagri14 # StockMarket # stocks # Bitcoin # stockmarketcrash # marketcrash # StockMarketindia # BitcoinCrash Bitcoin https : //t.co/HpjLHjiNYI
#
#
# Tweet ID: 944880
# Text: If 're tired losing money trading # Bitcoin # stockmarketcrash # Binance # forex # forextrading # forextrader # Terra # Lunacrash https : //t.co/lASrAGCTHS
#
#
# Tweet ID: 950037
# Text: In last 4 months 35 trillion dollars wealth destruction occurred n't even started taking liquidity markets yet . The shit show n't even started yet . # Bitcoin # economy # stockmarketcrash # inflation
#
#
# Tweet ID: 965215
# Text: BTC leveraged Long ATH .... What happens next ? # stockmarketcrash # Bitcoin # terraluna # leveragedtoken # trading https : //t.co/EGNmyZ3B7z
#
#
# Tweet ID: 971232
# Text: Job Market lags behind stock market 6 months . Layoffs adjustments happening 2nd half 2022 . Plan accordingly # stock # stockmarketcrash # marketcrash # Binance # Bitcoin # Crypto # cryptotrading # cryptocurrency # Cryptocrash
#
#
# ==================================================
#
# Hashtag: Bollinger
# Number of associated tweets: 38
#
# Hashtag: Bollinger
#
# Tweet ID: 892112
# Text: DOWN - APE/USDT Price:5.52800 RSI ALERTS FourHour RSI Calculation : 19.69 # BTC # DAIUSDT # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 2:18:38 AM
#
#
# Tweet ID: 894102
# Text: Pairs : ETHUSDT BUY:2142.53000 Time :5/12/2022 3:28:21 AM Average Decision : 52.17058FifteenMinutes Estimated Direction : UP # BTC # IDEXBNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 3:29:14 AM
#
#
# Tweet ID: 895652
# Text: Pairs : ETHUSDT SELL:2120.79000 Time :5/12/2022 4:34:34 AM Average Decision:40.85787 FifteenMinutes Estimated Direction : DOWN # BTC # BETABNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 4:34:52 AM
#
#
# Tweet ID: 899324
# Text: DOWN - ETH/USDT Price:1942.80000 RSI ALERTS FifteenMinutes RSI Calculation : 19.17 # BTC # MFTBNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 7:16:42 AM
#
#
# Tweet ID: 900925
# Text: DOWN - ETH/USDT Price:1878.81000 RSI ALERTS OneHour RSI Calculation : 18.67 # BTC # ENSBUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 8:05:17 AM
#
#
# Tweet ID: 913791
# Text: Pairs : ETHUSDT BUY:1974.38000 Time :5/12/2022 1:50:59 PM Average Decision : 55.39636FifteenMinutes Estimated Direction : UP # BTC # LTCBNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 1:51:20 PM
#
#
# Tweet ID: 915078
# Text: Pairs : BTCUSDT BUY:29127.81000 Time :5/12/2022 2:25:37 PM Average Decision : 59.77867FifteenMinutes Estimated Direction : UP # BTC # CMTETH # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 2:26:53 PM
#
#
# Tweet ID: 915105
# Text: Pairs : ETHUSDT SELL:2009.99000 Time :5/12/2022 2:25:49 PM Average Decision:47.62095 FifteenMinutes Estimated Direction : DOWN # BTC # AMPBTC # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 2:27:24 PM
#
#
# Tweet ID: 916335
# Text: Pairs : BTCUSDT SELL:28619.99000 Time :5/12/2022 3:01:10 PM Average Decision:49.04345 FifteenMinutes Estimated Direction : DOWN # BTC # ATOMEUR # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 3:01:27 PM
#
#
# Tweet ID: 926325
# Text: Pairs : ETHUSDT BUY:2013.36000 Time :5/12/2022 7:39:21 PM Average Decision : 52.44680FifteenMinutes Estimated Direction : UP # BTC # PAXTUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 7:39:51 PM
#
#
# Tweet ID: 927855
# Text: Pairs : ETHUSDT SELL:1990.07000 Time :5/12/2022 8:26:31 PM Average Decision:49.20935 FifteenMinutes Estimated Direction : DOWN # BTC # SANDAUD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 8:26:59 PM
#
#
# Tweet ID: 929221
# Text: Pairs : BTCUSDT SELL:28629.00000 Time :5/12/2022 9:13:57 PM Average Decision:44.08441 FifteenMinutes Estimated Direction : DOWN # BTC # AXSBNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 9:14:08 PM
#
#
# Tweet ID: 933199
# Text: DOWN - AVAX/USDT Price:29.67000 RSI ALERTS FourHour RSI Calculation : 17.04 # BTC # BALUSDT # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 11:39:10 PM
#
#
# Tweet ID: 933416
# Text: DOWN - 1INCH/USDT Price:0.80500 RSI ALERTS FourHour RSI Calculation : 18.04 # BTC # FLUXUSDT # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 11:48:08 PM
#
#
# Tweet ID: 933584
# Text: Pairs : BTCUSDT BUY:28769.98000 Time :5/12/2022 11:53:46 PM Average Decision : 50.80591FifteenMinutes Estimated Direction : UP # BTC # KAVAUSDT # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 11:54:10 PM
#
#
# Tweet ID: 933775
# Text: DOWN - SHIB/USDT Price:0.00001 RSI ALERTS FourHour RSI Calculation : 11.08 # BTC # MANABUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 12:00:41 AM
#
#
# Tweet ID: 934320
# Text: Pairs : BTCUSDT SELL:28327.92000 Time :5/13/2022 12:24:02 AM Average Decision:38.56510 FifteenMinutes Estimated Direction : DOWN # BTC # UFTBUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 12:24:13 AM
#
#
# Tweet ID: 934903
# Text: DOWN - DOGE/USDT Price:0.08090 RSI ALERTS FourHour RSI Calculation : 19.88 # BTC # CITYBNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 12:52:46 AM
#
#
# Tweet ID: 935024
# Text: DOWN - CHZ/USDT Price:0.09570 RSI ALERTS FourHour RSI Calculation : 18.47 # BTC # RPXBNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 12:57:48 AM
#
#
# Tweet ID: 935634
# Text: DOWN - DOT/USDT Price:8.27000 RSI ALERTS FourHour RSI Calculation : 18.65 # BTC # USDSBUSDS # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 1:23:50 AM
#
#
# Tweet ID: 937990
# Text: Pairs : ETHUSDT SELL:1956.46000 Time :5/13/2022 3:12:38 AM Average Decision:48.44879 FifteenMinutes Estimated Direction : DOWN # BTC # GMTAUD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 3:13:00 AM
#
#
# Tweet ID: 941103
# Text: Pairs : ETHUSDT BUY:2057.84000 Time :5/13/2022 8:09:10 AM Average Decision : 53.93940OneHour Estimated Direction : UP # BTC # HIGHBTC # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 5:37:15 AM
#
#
# Tweet ID: 947252
# Text: Pairs : ETHUSDT SELL:2091.19000 Time :5/13/2022 12:51:21 PM Average Decision:48.41836 OneHour Estimated Direction : DOWN # BTC # BCHBNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 10:15:19 AM
#
#
# Tweet ID: 948251
# Text: Pairs : ETHUSDT SELL:2052.00000 Time :5/13/2022 10:58:02 AM Average Decision:44.15437 FifteenMinutes Estimated Direction : DOWN # BTC # REEFBIDR # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 10:58:22 AM
#
#
# Tweet ID: 948995
# Text: Pairs : ETHUSDT BUY:2066.46000 Time :5/13/2022 11:29:34 AM Average Decision : 55.47697FifteenMinutes Estimated Direction : UP # BTC # ICNETH # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 11:29:54 AM
#
#
# Tweet ID: 952004
# Text: Pairs : AVAXUSDT SELL:34.34000 Time :5/13/2022 4:03:35 PM Average Decision:49.08985 OneHour Estimated Direction : DOWN # BTC # GALAETH # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 1:27:37 PM
#
#
# Tweet ID: 952654
# Text: Pairs : ETHUSDT BUY:2094.20000 Time :5/13/2022 4:31:23 PM Average Decision : 57.66661OneHour Estimated Direction : UP # BTC # TORNBUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 1:55:10 PM
#
#
# Tweet ID: 953264
# Text: Pairs : AVAXUSDT BUY:34.68000 Time :5/13/2022 4:56:35 PM Average Decision : 50.69783OneHour Estimated Direction : UP # BTC # API3BNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 2:20:42 PM
#
#
# Tweet ID: 963474
# Text: Pairs : AVAXUSDT SELL:35.55000 Time :5/13/2022 9:32:25 PM Average Decision:46.21633 OneHour Estimated Direction : DOWN # BTC # WINBTC # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 6:58:44 PM
#
#
# Tweet ID: 966788
# Text: Pairs : ETHUSDT BUY:2074.66000 Time :5/13/2022 8:00:55 PM Average Decision : 55.37075FifteenMinutes Estimated Direction : UP # BTC # STORMBTC # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 8:11:20 PM
#
#
# Tweet ID: 966839
# Text: Pairs : BTCUSDT SELL:29998.45000 Time :5/13/2022 10:38:38 PM Average Decision:49.79998 OneHour Estimated Direction : DOWN # BTC # SHIBGBP # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 8:12:20 PM
#
#
# Tweet ID: 966889
# Text: Pairs : ETHUSDT SELL:2071.91000 Time :5/13/2022 10:39:04 PM Average Decision:45.41741 OneHour Estimated Direction : DOWN # BTC # NASBTC # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 8:13:20 PM
#
#
# Tweet ID: 971339
# Text: Pairs : ETHUSDT BUY:2072.36000 Time :5/13/2022 10:09:41 PM Average Decision : 57.12765FifteenMinutes Estimated Direction : UP # BTC # RPXETH # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 10:10:02 PM
#
#
# Tweet ID: 973472
# Text: Pairs : BTCUSDT SELL:29970.32000 Time :5/14/2022 1:42:36 AM Average Decision:47.12459 OneHour Estimated Direction : DOWN # BTC # LRCBUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 11:06:38 PM
#
#
# Tweet ID: 974952
# Text: Pairs : ETHUSDT SELL:2047.85000 Time :5/13/2022 11:54:48 PM Average Decision:41.66167 FifteenMinutes Estimated Direction : DOWN # BTC # ETCBUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 11:55:13 PM
#
#
# Tweet ID: 975950
# Text: Pairs : BTCUSDT BUY:29885.34000 Time :5/14/2022 12:28:34 AM Average Decision : 58.57854FifteenMinutes Estimated Direction : UP # BTC # MATICBUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 12:28:46 AM
#
#
# Tweet ID: 975964
# Text: Pairs : ETHUSDT BUY:2052.78000 Time :5/14/2022 12:28:41 AM Average Decision : 52.52144FifteenMinutes Estimated Direction : UP # BTC # TOMOBNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 12:29:17 AM
#
#
# Tweet ID: 978639
# Text: Pairs : ETHUSDT SELL:2044.50000 Time :5/14/2022 2:10:32 AM Average Decision:44.13590 FifteenMinutes Estimated Direction : DOWN # BTC # CLOAKETH # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 2:10:58 AM
#
#
# ==================================================

# %% [markdown]
# #### Hashtag and tweets second period

# %%
# Select the time window of the first period
start_date = pd.to_datetime('2022-06-14').date()
end_date = pd.to_datetime('2022-06-17').date()

# Filters the DataFrame for the specified dates
filtered_df = df_sentiment[(df_sentiment['date'] >= start_date) & (df_sentiment['date'] <= end_date) & (
            df_sentiment['Sentiment'] == 'Negative')]

# Control column type hashtag
filtered_df['hashtags'] = filtered_df['hashtags'].astype(str)
# Out:
# /var/folders/j_/9989vv3d7z7c61s49rkzydxm0000gn/T/ipykernel_88167/2363845779.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['hashtags'] = filtered_df['hashtags'].astype(str)

# %% [markdown]
# #### Most influential hashtags

# %%
# Call the function for print influent hashtag
hashtagInfluent_period(filtered_df)
# Out:
# The 150 most influential hashtags in the period of interest:
# ['DroverInu', 'DroverToken', 'Cryptocrash', 'Forex', 'Trading', 'BabyDogeCoin', 'Game', 'METAVERSE', 'Money', 'Cryptos', 'BitcoinCrash', 'EURUSD', 'CryptoMarket', 'bearmarket', 'Luna', 'Btc', 'CryptocurrencyNews', 'TRX', 'metaverse', 'FOMC', 'altcoins', 'Etherum', 'GBPUSD', 'Coinbase', 'Celsius', 'coinbase', 'Frzss', 'investing', 'Blockchain', 'NFTGiveaway', 'HODL', 'inflation', 'nfts', 'xrp', 'memecoin', 'Fed', 'BTCUSD', 'stocks', 'RsiBitcoin', 'defi', 'doge', 'bitcoinnews', 'CRYPTO', 'Cardano', 'cripto', 'news', 'Gamefi', 'LUNA', 'pancakeswap', 'bscgems', 'bschunter', 'birdbro', 'birdbrofamily', 'birdbrocn', 'birdbrobr', 'birdbroarmy', 'birdbrotoken', 'web3', 'birdbropt', 'P2E', 'Altcoins', 'NFTCommmunity', 'NASDAQ', 'zoomout', 'ada', 'BTCs', 'game', 'Gold', 'StockMarket', 'sol', 'cryptocrash', 'BTCUSDT', 'opensea', 'gold', 'stockmarketcrash', 'CelsiusNetwork', 'fintech', 'CyclicalInvesting', 'luna', 'cro', 'forex', 'crofam', 'art', 'meta', 'investment', 'artist', 'bitcoins', 'LUNC', 'SatoshiSwap', 'BTCsMining', 'RSİ', 'cryptocomnft', 'Bollinger', 'AI', 'FederalReserve', 'shiba', 'cryptocom', 'CronosNFT', 'LoadedLions', 'crofamily', 'cronosgem', 'BinanceSmartChain', 'CRO', 'nftartist', 'HEX']

# %% [markdown]
# #### Tweets containing the hashtags

# %%
# List of hashtags of interest
list_hashtag_interest = ['BitcoinCrash','bearmarket','inflation','cryptocrash','stockmarketcrash','Bollinger']

# %%
# Call the function with the list of hashtags
see_tweet_on_hashtag(filtered_df, list_hashtag_interest)
# Out:
# Hashtag: BitcoinCrash
# Number of associated tweets: 177
#
# Hashtag: BitcoinCrash
#
# Tweet ID: 1206095
# Text: Everything comes Cycles ! Lets hope isnt one long ones ! # Bitcoin # BitcoinCrash # BTC https : //t.co/YOgqyNSOWe
#
#
# Tweet ID: 1206428
# Text: Explaining reasons behind crypto crash . # Celsius # BTC # BitcoinCrash # Cryptocrash https : //t.co/nCDWYnvp6w
#
#
# Tweet ID: 1206733
# Text: # Democrats & amp ; # DNC failed leadership crime , food prices , gas prices , time high rents , Stocks crypto plunging , BUT ORANGE MAN GONE ! ! # BidenGasHike Blame Democrats Blame Biden # BidenWorstPresidentEver # Biden # BitcoinCrash # BTC # ETH # NFT https : //t.co/ndd6AYJFSl
#
#
# Tweet ID: 1206898
# Text: Elephants fight , ants crushed . # bitcoin # btc # BitcoinCrash # Crypto # CryptoMarket
#
#
# Tweet ID: 1207460
# Text: MicroStrategy threatened margin call due fall # BTC 👉https : //t.co/VfbSSNZo1v # BitcoinCrash # Binance https : //t.co/TKTmlyDQBl
#
#
# Tweet ID: 1207597
# Text: How Tuesday going ? These today 's closed trades , trades I take I give # YouTube livestreams . I go # crypto & amp ; # forex Tune , pay attention , make money 💪✌️ # Gold # stocks # Cryptos # Cryptocrash # BTC # BitcoinCrash # Bitcoin # NFT https : //t.co/Ssi0K81E47
#
#
# Tweet ID: 1207606
# Text: Invest # bitcoin late 😎 The king cryptocurrency 💯 . # BITCOIN # BitcoinCrash # BTC # MEMES # memes2022 # Bitcoinmemes # cryptocurrency # crypto # CryptoNews # CryptoBOT https : //t.co/2IPgtTvWBl
#
#
# Tweet ID: 1208472
# Text: # Bitcoin whale game # cryptocurrency # BTC # altcoin # CryptoMarket # BitcoinCrash # BitcoinButton Link - https : //t.co/4BMq0dEsN3 https : //t.co/MUdeCZxPkL
#
#
# Tweet ID: 1208707
# Text: Would silly dollar cost average ( dca ) levels opinion # BitcoinCrash # Bitcoin # Btc # ETH # Ethereum Eth $ 1200 Btc $ 22000 Link $ 6.20 Dot $ 7.30 Yes , things go much lower , couple months ago excited buy 3x+ prices
#
#
# Tweet ID: 1208809
# Text: Can Bitcoin rise like phoenix Black Monday ? https : //t.co/iMOQdTOmPa # Bitcoin # BitcoinCrash # bitcoins # Cryptocrash # cryptocurrency # CryptocurrencyNews # BTC # BTCUSD # Binance # Celsius # CelsiusNetwork # CryptoNews
#
#
# Tweet ID: 1208873
# Text: ‼️Tomorrow wed 15 june FOMC / Funds rate . Expect heavy volatility crypto market . BEWARE leverage positions standing . # FOMC # BitcoinCrash # BTC # Ethereum # stockmarketcrash # CryptoMarket https : //t.co/0LJvYWOEi6
#
#
# Tweet ID: 1209022
# Text: # stockmarketcrash # BitcoinCrash @ CNBC @ federalreserve $ appl @ elonmusk # CryptoMarket # cryptocurrency . It took 5 days # BTC go From 31K 21K inflation 8.6 % YOY . The existence # BTC asset hedge inflation . Either fraud investors dumb
#
#
# Tweet ID: 1209088
# Text: # BitcoinCrash & amp ; # Cryptocrash - 's bottom ? It 's rough 's Tuesday . 🙄 # BTC https : //t.co/CETmYc1kTN
#
#
# Tweet ID: 1209482
# Text: I love times like crypto . All weak hands scammers usually exit door left # crypto # Cryptocrash # BitcoinCrash # bitcoin # btc # Ethereum # eth
#
#
# Tweet ID: 1209527
# Text: The # Bitcoin greed fear index all-time low . The mood extremely fearful . # BitcoinCrash # Bitcoin2022 # btc # BTCUSDT # btc # Crypto # cryptocurrency https : //t.co/jXKjoFpHJK
#
#
# Tweet ID: 1209797
# Text: @ rovercrc Not see 10 , fuck people boring range 25-35 # BTC # BitcoinCrash
#
#
# Tweet ID: 1210034
# Text: POOR COIN 32K To 20K 🔻 Maybe The Crash Test 17K # Binance # BitcoinCrash # BTCUSDT # BTC # bitcoin # Cryptocrash # Cryptos https : //t.co/XqDpqoadvC
#
#
# Tweet ID: 1210092
# Text: The News wants focus # cryptocrash instead # inflation # Biden # recession , # depression caused massive money printing stupid government spending . # hodl # btc # BitcoinCrash https : //t.co/B1EdB20WYq
#
#
# Tweet ID: 1210103
# Text: $ BTC # BTC # BitcoinCrash Just wary guys , I think might nasty , downright evil fakeout . Take precautions case ! https : //t.co/7zWXUKk0vd
#
#
# Tweet ID: 1210513
# Text: When corrupt unstable countries world adopt bitcoin , understand bitcoin ! Trash ! # BitcoinCrash # BTC $ BTC
#
#
# Tweet ID: 1210589
# Text: If use bitcoin evade government , government manipulates bitcoin prices gives hard lesson . # BitcoinCrash # BTC $ BTC
#
#
# Tweet ID: 1210615
# Text: $ ETH # ETH # ETEHERUM SP $ 1612 . There bounce I expected would . Now hold keep going ? ! ? Lets see . # BTC # BitcoinCrash # BTCUSDT # bitcoin # coin $ coin # stocks # gold $ gold # silver $ silver https : //t.co/LwV6J5eHvj https : //t.co/bluucIcBpZ
#
#
# Tweet ID: 1210641
# Text: Bitcoin Breaking resistance ! Is finally time infamous inverse head shoulders pattern play ? 🤔 # BitcoinCrash # BITCOIN # btc https : //t.co/JkyEzVYIyS
#
#
# Tweet ID: 1211002
# Text: Bitcoin Fear Greed Index 8 . Extreme Fear Current price : $ 22,616 # BTC # BitcoinCrash # Bitcoin # BitcoinButton # Binance # Cryptos https : //t.co/5iGGZ5rwFv
#
#
# Tweet ID: 1211557
# Text: Nobody believes ’ late 😂 😂 I said ’ chose listen . Y ’ chose listen moon-boys instead . # BitcoinCrash # BTC # Bitcoin # callme_eco # princeeco2 # Cryptos # Crypto # cryptocurrency https : //t.co/coqOuY9bYe
#
#
# Tweet ID: 1211590
# Text: Just little go 🙂 # BTC # BitcoinCrash
#
#
# Tweet ID: 1211667
# Text: For long Crypto ? # CryptoMarket # BitcoinCrash # Bitcoin # Binance # Cryptos # cryptocurrency # BTC
#
#
# Tweet ID: 1211985
# Text: Hy Tell Fam 😎💥 Half 28.8k equal to______ ? # Bitcoin # BTC # BitcoinCrash # cryptocurrency Clue 🗝️ 🧩 🤪
#
#
# Tweet ID: 1212107
# Text: Last month ordered Animal latex monkey mask 🐒 @ ape_swap continuous build . Got mail today package shipped china , Let 's see use entertainment promote crypto market @ Obie_Dobo 🚀 🍌 🍌 🍌 🍌 # Cryptos # DeFi # BTC # BNB # BitcoinCrash
#
#
# Tweet ID: 1212115
# Text: @ PeterSchiff The current pair trade makes sense ! ⬆️ LONG $ GOLD || $ BTC SHORT ⬇️ 📈 The chart presents $ GOLD vs $ BTC ratio trending since November last year . $ GLD # Gold # Bitcoin # BTC # BitcoinCrash https : //t.co/DOv8U6aV2I
#
#
# Tweet ID: 1212263
# Text: 19 number hate coz # Covid_19 But , # 19thcentury time Thomas Alva Edison created lamp bring light us Maybe # 19k lamp need save us darkness 😇 # cryptocurrency # Crypto # CryptoMarket # BitcoinCrash # BTC # Cryptos https : //t.co/63CqIIHAjO
#
#
# Tweet ID: 1213263
# Text: Trade carefully 🙏 # Cryptos # stocks falling invest afford loose worse yet come brace impact # BTC # NASDAQ # CryptocurrencyNews # Ethereum # altcoins # BitcoinCrash # AVAX # atom # sol # LUNA # ada # altcoins # stockmarketcrash $ btc # CelsiusNetwork https : //t.co/ma1ch5DSD7
#
#
# Tweet ID: 1214284
# Text: When market bear , The whales happy.i know small investors cry .. # Crypto # Cryptos # cryptocurrency # CryptoNews # cryptocommunity # BitcoinCrash # Bitcoin # BTCUSD # BTC # ETH # ADA # Solana # LUNA # Polygon # nftart # NFT # NFTs # Ethereum # Celsius # SolanaNFT # bitcoin $ btc # bnb
#
#
# Tweet ID: 1214470
# Text: Capitulation near hand tight # BitcoinCrash # Bitcoin # btc # Cryptos # crypto # CryptoMarket # eth # Etherum $ btc $ eth # Binance # coinbase # NFT # NFTCommunity # byac # Celcius https : //t.co/IZ1l8y1JfP
#
#
# Tweet ID: 1214590
# Text: $ 22k become new $ 30k… previously $ 38k… # Bitcoin # BitcoinCrash # BTC $ BTC # crypto # cryptocurrencies # cryptocurrency # cryptotrading
#
#
# Tweet ID: 1215668
# Text: Bitcoin may fall less dollar . # BitcoinCrash # BTC $ BTC
#
#
# Tweet ID: 1215778
# Text: The thing bitcoin 1 ) surges , currency measure wealth . 2 ) falls stays stable , investment offer return investors . So , bitcoin ? A bet thin air . # BitcoinCrash # BTC $ BTC
#
#
# Tweet ID: 1216137
# Text: # Cryptocrash # BitcoinCrash Is # BTC going less $ 10000 end month ?
#
#
# Tweet ID: 1217221
# Text: # Bitcoin visiting lows tonight . 15 min candle closed support . # BitcoinCrash https : //t.co/XqCFPoTAl3
#
#
# Tweet ID: 1217614
# Text: To heavy hearts harbouring loss funds recent dip , My sincere condolences❤️.it 's game chose , play like matured man # SayNoToSucide # Bitcoin # BitcoinCrash # NFT # BitcoinCrash # crypto # cryptocrash # NFTs # ETH # Web3
#
#
# Tweet ID: 1217664
# Text: # Bitcoin dropped 55.61 % 6 months . Our prediction get past $ 15k maybe normalise around $ 10k $ 12k . Thoughts ? # Cryptocrash # cryptocurrency # BitcoinCrash # doggy https : //t.co/OPpuelRlvf
#
#
# Tweet ID: 1218069
# Text: Why n't invest Bitcoin 's safe coin world . I see 🤣✅ You crypto knowledge . I 'll give secret ! There 's new coin take . It happen soon . Everyone hate crypto . # BitcoinCrash # Bitcoin
#
#
# Tweet ID: 1218118
# Text: RIP # bitcoin 19k incoming This year next tough 2024 / 2025 ’ start see progress # Bitcoin # BitcoinCrash
#
#
# Tweet ID: 1218306
# Text: This right peak crypto-fear . If still sticking Crypto truly holder go worst bear markets . # Crypto # ETH # CryptoMarket # Bitcoin # BitcoinCrash # etvScandal # Ethereum # BTC
#
#
# Tweet ID: 1219058
# Text: # AmberHeardIsALiar # Bitcoin # BitcoinCrash # BTC # BTSFESTA2022 # Burnaboy # Bajwa # BREAKING # DementiaJoe Biden everything 2 stop Putins ' gas tax hike sending Rolaids . Antacid Tablets . SHIT ? https : //t.co/bi89DQnb2z
#
#
# Tweet ID: 1219294
# Text: BOTTOM LINE # BIDEN & amp ; TEAM DO NOT GIVE A CRAP us ... $ TSLA # Bitcoin # BitcoinCrash # ETH $ SPY $ GME $ AMC $ AAPL # Federal https : //t.co/UqAsCgTDZo
#
#
# Tweet ID: 1219539
# Text: Waking crypto crash sucks ! # cryptocurrency # cryptocrash # BitcoinCrash # Bitcoin https : //t.co/IMk4hpmbkM
#
#
# Tweet ID: 1219605
# Text: WhaleBot Alerts 🐳 : 🚨🚨🚨🚨🚨 2,507 BTC ( $ 54,073,584 ) transfered Unknown Unknown 🚨🚨🚨🚨🚨 2,545 BTC ( $ 54,902,508 ) transfered Unknown Unknown # btc # bitcoins # selling # pressure # dump # pump # buying # FTX # Binance # KuCoin # huobi # kraken # BitcoinCrash # Bitfinex
#
#
# Tweet ID: 1219875
# Text: # Bitcoin Daily Chart 📈 Hidden Bullish Divergence ? 👀🤷‍♂️ # BTC # ETH # cryptocurrency # CryptoMarket # cryptocurrencies # BitcoinCrash # cryptotrading https : //t.co/Tsy6xwX4vA
#
#
# Tweet ID: 1220921
# Text: would funny sad # Cryptocrash # cryptocurrency # Crypto # BitcoinCrash # CryptoNews # Bitcoin # NFT # NFTs # NFTCommmunity # BTC https : //t.co/oSYT7Lcmko
#
#
# Tweet ID: 1221144
# Text: Prices insane today , big time steal buying market . # Crypto # ETH # BitcoinCrash # Bitcoin # Binance # NFTs # nftart https : //t.co/N2n6MaAFPQ
#
#
# Tweet ID: 1221167
# Text: That simply insane # Crypto # ETH # BitcoinCrash # Bitcoin # Binance # NFTs # nftart
#
#
# Tweet ID: 1221221
# Text: That said , separate good mediocre additional fund raising rounds likely hard come move forward year # Crypto # ETH # BitcoinCrash # Bitcoin # Binance # NFTs # nftart
#
#
# Tweet ID: 1221223
# Text: Don ’ let rob financial freedom # FUD # HOLD onto assets believe long term @ Shiryo_Official # SHIRYO # TCG # Pokemon # NFTs # NFTGaming # playtoearn # Metaverse # BTC # ETH # Cryptocrash # BitcoinCrash # Crypto
#
#
# Tweet ID: 1221298
# Text: If overwhelmed chaos times , anchor thought life something predictable , reliable , constant , fruitful . # Bitcoin # bitcoinnews # BitcoinCrash
#
#
# Tweet ID: 1221372
# Text: So sad . # Celsius # CelsiusNetwork # Bitcoin # BitcoinCrash # Crypto # ETH https : //t.co/oInkWgejWt
#
#
# Tweet ID: 1221411
# Text: believe photo , reality even less # Cryptocrash # cryptocurrency # Crypto # BitcoinCrash # CryptoNews # Bitcoin # NFT # NFTs # NFTCommmunity # BTC https : //t.co/pC66YL0osW
#
#
# Tweet ID: 1221507
# Text: # Bitcoin # BitcoinCrash Bitcoin fall $ 3000 _ $ 4000 USD mid late 2023 ! https : //t.co/eLIUvhu0Wk
#
#
# Tweet ID: 1221511
# Text: WOW ! ! ! So $ 20 dollars # Bitcoin # BitcoinCrash past 5 months … imagine bought millions https : //t.co/cyReONnuB7
#
#
# Tweet ID: 1221649
# Text: game ’ called find red - I n't find either ! # Cryptocrash # cryptocurrency # Crypto # BitcoinCrash # CryptoNews # Bitcoin # NFT # NFTs # NFTCommmunity # BTC https : //t.co/LsUzrlxI4l
#
#
# Tweet ID: 1223775
# Text: Usually McDonald ’ memes start bottom sight . May indicative technical chart ! Is $ 20k gon na hold gon na apply ? # Bitcoin # BitcoinCrash # Ethereum # drcrypto https : //t.co/nigtweFvPQ
#
#
# Tweet ID: 1224202
# Text: Future Trade Btc/Usdt ( Long ) Entry : - 21850-22050 Targets : - 22500 23000 23500 Stop loss : - 21500 # Bitcoin # BTC # BitcoinCrash # cryptocurrencies # DayTrading # CryptoSignals
#
#
# Tweet ID: 1225098
# Text: # TRON # TRX Can # rugpull # USDD # StableCoin lost benchmark , Please careful stay # DYOR ... # TRONICS # TronNetwork # trxmining # Cryptocrash # CryptoNews # cryptocurrency # BitcoinCrash # Bitcoin # Binance # BNB https : //t.co/r8C0lXTZzK via @ YouTube
#
#
# Tweet ID: 1226410
# Text: # Binance Reveals Incident That Forced It Freeze # BTC Withdrawals https : //t.co/ad2FnNsKc8 # Cryptocrash # stockmarketcrash # bearmarket # BitcoinCrash # Cryptos # NFTCommmunity
#
#
# Tweet ID: 1227054
# Text: The News wants focus # cryptocrash instead # inflation # Biden # recession , # depression caused massive money printing stupid government spending . # hodl # btc # BitcoinCrash https : //t.co/utCCUCmyoj
#
#
# Tweet ID: 1227158
# Text: London bridge fallen fallen ohhj sorry Bitcoin Bridge fallen fallen dear trader 😭😭😭😭😂 # Bitcoin # CryptoNews # BitcoinCrash # Nigeria $ BTC
#
#
# Tweet ID: 1227307
# Text: `` If # Bitcoin collapse 70 % $ 69,000 $ 21,000 , easily fall $ 6,000 . Given excessive leverage # crypto , imagine forced sales would take place '' , says # PeterSchiff # BTC # BitcoinCrash # Cryptocurrency # StockMarket https : //t.co/RgptDBout0
#
#
# Tweet ID: 1227451
# Text: $ btc If ends hitting bear market , mad ? # Cryptocrash # Cryptos # cryptocurrency # Bitcoin # BitcoinCrash https : //t.co/N1fEX9KdLq
#
#
# Tweet ID: 1227749
# Text: Buying # Bitcoin everyday ! # BitcoinCrash https : //t.co/4ks9EwgrgP
#
#
# Tweet ID: 1228425
# Text: Be careful , snow crash coming. # BitcoinCrash # Bitcoin # Ethereum # MANA # Decentraland # PlayToEarn https : //t.co/QOd11gCGAM
#
#
# Tweet ID: 1228619
# Text: # BREAKING # BreakingNews The ridiculous scam since tulip mania plunges $ 21,000 # Bitcoin # BitcoinCrash # Cryptocrash # Crypto # CrapCurrencies # CryptoNews https : //t.co/bEAQ8ahboU
#
#
# Tweet ID: 1228769
# Text: # BitcoinCrash # BTC THE END OF # BITCOIN ? If # BTC dead coin lead Market ! !
#
#
# Tweet ID: 1229104
# Text: time long ? # BTC # Bitcoin # BitcoinCrash https : //t.co/zeShEj9F1D
#
#
# Tweet ID: 1229596
# Text: I screen recorded # BitcoinCrash charting . Local bottom mean THE bottom . The $ DXY , # US30 , # NASDAQ , # SPX , $ BTC.D , # Bitcoin telling story . FED wrecking ball may smash supports . Song : Critical Acclaim A7X https : //t.co/4IHQANBHn5
#
#
# Tweet ID: 1231233
# Text: The # Crypto # Bitcoin situation serious , even tweet elon musk positiv effect ☝️ # Cryptocurrency # CryptoCrash # BitcoinCrash # BTC # Ethereum # ETH # Doge # DogeCoin https : //t.co/iZfRrLOizW
#
#
# Tweet ID: 1233254
# Text: $ BTC / $ USD - Update Hard say wave 5 finish , signs demand far careful longing every bounce , break market structure LTFs 👍 # btc # bitcoins # BitcoinCrash # Ethereum # dogecoin https : //t.co/Nz9T39VWyp
#
#
# Tweet ID: 1234333
# Text: 👑The king speaks ... Btc oversold capped negative line The bear market last longer period time If n't serious buy pressure BTC paint bullish flag fall 18000 & gt ; 16000 Screenshot # BitcoinCrash # Bitcoin # CryptoNews # BTC
#
#
# Tweet ID: 1234412
# Text: Trends come go , # Domains stay ! # DeSoc # Web5 related domains high value . Do n't fooled fake bids ! # DeFi # BitcoinCrash # BTC # ETH 👇 # DigitalAssets # CyberSecurity https : //t.co/XgtnZYhYQN
#
#
# Tweet ID: 1234713
# Text: - Today # Bitcoin price -- & gt ; $ 21500📉 - Fear & amp ; Greed Index -- & gt ; 7 points ( Extreme Fear ) 🔥 You look market tab 🌐 https : //t.co/vrfwXvmaCy # markets # BitcoinCrash # Cryptocrash # Cryptos # CryptoMarket # CryptocurrencyNews # NFTs https : //t.co/rX9UHac46b
#
#
# Tweet ID: 1235490
# Text: At Extreme Fear : 7 . Time move ? $ BTC # BTC # Bitcoin # BitcoinCrash # Cryptocrash https : //t.co/GCXdlusS74
#
#
# Tweet ID: 1235676
# Text: Will # Bitcoin fall $ 20,000 ? It ’ wait see game 👀 # BTCUSD # btc # Crypto # CryptoMarket # cryptocurrency # Cryptocrash # BitcoinCrash https : //t.co/pywSfu40xP
#
#
# Tweet ID: 1235722
# Text: The market looks powerless rn .... # BTC # Bitcoin # Cryptocrash # CryptoSignals # Cryptos # CryptoMarket # BitcoinCrash # bitcoins # CryptoNews # cryptocurrency https : //t.co/Y228rS0I58
#
#
# Tweet ID: 1236032
# Text: Testing previous cycle 's high earlier I 'd expected ..... # Bitcoin # BitcoinCrash # btc # CryptoMarket # Cryptocrash # cryptocurrency # CryptoNews
#
#
# Tweet ID: 1236054
# Text: # BitcoinCrash # BTC unable break downtrend line smaller timer frames . This shows lack strength market . The major support $ 19,500- $ 20,000 area lot liquidity zone . WAIT FOR ENTRY https : //t.co/sdtxJdXb2i
#
#
# Tweet ID: 1236312
# Text: I n't care bearish # crypto gets , leave , long haul # BitcoinCrash # bitcoin # bearmarket # BTC # ETH # BNB # XRP
#
#
# Tweet ID: 1237340
# Text: # BitcoinCrash # Bitcoin 20k I told , n't stupid . But laugh 2021 . Now laughing ? Who laughing right ? I told . # Schweiz # Deutschland # Oesterreich # Zürich # Berlin # Wien # München # Bern # USA # UK # Canada # Australia # NewZealand https : //t.co/r5R6FWEBK1
#
#
# Tweet ID: 1237676
# Text: # Crypto Market # bloodbath , # Bitcoin 's non stop 9 red candles . $ 10k 10 days . Crazy expected # crash . # BitcoinCrash # Crypto # bearmarket # HODL https : //t.co/8GYHqs8S8K
#
#
# Tweet ID: 1237910
# Text: Call crazy I wan na buy DIP . Tip : Place buy orders desired amount ! Buy sustainable projects # Cryptocrash # Crypto # btc # Bitcoin # Ethereum # ICP # Algorand # Chainlink # HBAR # altcoins # MATIC # Enjin # XRP # ADA # Cardano # Polkadot # BitcoinCrash # buythedip # DutchX7
#
#
# Tweet ID: 1238156
# Text: IMO # bitcoin bottom 14k 16.5k . worst case scenario 11k -12k # BitcoinCrash # Cryptocrash
#
#
# Tweet ID: 1238233
# Text: @ whale_alert Meaning tha base currencies quotes / denominates going ⬇️ ( things equal ) Exchange data , technical & amp ; fundamental outlook point downside price action relief bounce # Bitcoin # BitcoinCrash # Celsius # 3AC | The Fed FOMC # recession # inflation
#
#
# Tweet ID: 1238668
# Text: # bitcoin weekly chart . 200 weekly broken . A dump 22-28 % come . support zones marked chart . IMO bottom could somewhere 14-16k . worst case 11k-13k # Cryptocrash # CryptoMarket # BitcoinCrash https : //t.co/nAYjMeZnSz
#
#
# Tweet ID: 1239322
# Text: 3,346 ETH liquidated following wallet past hour : 0x716034C25D9Fb4b38c837aFe417B7f2b9af3E9AE ( supposedly related 3AC ) # BitcoinCrash # Bitcoin # Cryptocrash # CryptocurrencyNews # ETH # Ethereum
#
#
# Tweet ID: 1240033
# Text: That 's , maybe little crypto winter ! # Cryptocrash # CryptoNews # Bitcoin # BitcoinCrash https : //t.co/jJF8CXpYt1
#
#
# Tweet ID: 1241676
# Text: 13 % less 1min . # CrystalFutures # Solana # trading # Cryptos # CryptoMarket # Cryptocrash # bearmarket # Profits # BTC # Bitcoin # BitcoinCrash # Binance # CryptoMarket # Cryptos # HODL # FOMC # Etherum # fullmoon # usdtry https : //t.co/KrrtTmkDwo
#
#
# Tweet ID: 1241744
# Text: Crypto Investors failed book profit highs # investing # crypto # Cryptocrash # CryptoNews # Bitcoin # BitcoinCrash # trading https : //t.co/029LJVoQVF
#
#
# Tweet ID: 1241805
# Text: Clearly 's time wait see happen . Pay attention possible fake pump soon hits 20k . Invest afford lose . Remember life family . # Bitcoin # BitcoinCrash # crypto # cryptos # CryptoArmageddon
#
#
# Tweet ID: 1241900
# Text: Bitcoin price 2017 high . 5 Years gains wiped 6 months . Could worse come . # Bitcoin # btc # BitcoinCrash # Cryptocrash # cryptocurrency https : //t.co/wGb268n7d2
#
#
# Tweet ID: 1242060
# Text: I could wrong , I think # Bitcoin going back £10k , potentiolly even £5k # Cryptocrash # CryptoMarket # BitcoinCrash # NFT # NFTs # nftart # NFTartists # NFTshilling @ rarible # nftcollectors # NFTCommunity # nftmusic # NFTProject
#
#
# Tweet ID: 1242245
# Text: BE CAREFUL : # Bitcoin Next Move : 17000 16000 👀 15000 14000 👀 # btc $ btc # BitcoinCrash # Cryptocrash # CryptoMarket # CryptoNews # bearmarket
#
#
# Tweet ID: 1242510
# Text: Could Bitcoin completely tank ? I ’ know anything crypto stock market even crazy # BitcoinCrash # Bitcoin
#
#
# Tweet ID: 1242553
# Text: Bitcoin nearly 30 % past week . Some experts believe still go lower https : //t.co/jjLgzhES98 By @ decryptmedia # Bitcoin # btc # BitcoinCrash # Cryptocrash
#
#
# Tweet ID: 1242727
# Text: Salute buying # Bitcoin # BitcoinCrash As donating hard earn money selling # Bitcoin Sellers # Bitcoin responsible individuals r concerned abt future well family life Buyers r greedy n ignorant https : //t.co/S2W5jpka4i
#
#
# Tweet ID: 1243365
# Text: # BitcoinCrash # cryptocurrency # Bitcoin digital money - FAIL # Bitcoin store value - FAIL # Bitcoin inflation hedge - FAIL # Bitcoin recession hedge - FAIL What next bullshit bingo ?
#
#
# Tweet ID: 1243406
# Text: In pyramid scams like Bitcoin , someone always suffers loser part . # Bitcoin # BitcoinCrash # darwinism # intelligence # IQTest https : //t.co/rT0lqtHjGJ
#
#
# Tweet ID: 1244602
# Text: When said done , 's going wick left . A single line memory everyone got emotional gave . Do n't part memorial . # BitcoinCrash # btc # Cryptocrash
#
#
# Tweet ID: 1244730
# Text: 😂 crypto faint heart # Bitcoin # BitcoinCrash # CryptoMarket # bearmarket https : //t.co/EYjRLvER0r
#
#
# Tweet ID: 1245038
# Text: When “ Buy Dip ” , avocado 🥑isn ’ ripe 🤢 . Stop following trends hard earned money ! Say # youdezervbetter invest money experts today # Bitcoin # BitcoinCrash # finance # markets # dezerv # India https : //t.co/UtMHhhPKfa
#
#
# Tweet ID: 1246988
# Text: I may active trade sometimes 🥂🥂🤑🤑💰💰🚀🚀🚀✅ # btc # ETH # SOL # NFTGiveaway # NFTs # BitcoinCrash # bitcoin # Crypto # cryptocurrencies # FOMO # FOMC # TradingView # Signal # Trades # PROFIT # bearmarket # Bullish # CryptocurrencyNews # altcoinmarketcap https : //t.co/V41LC6foZR
#
#
# Tweet ID: 1247535
# Text: # Bitcoin Buying When cryptosuckers n't time wring pants . Washing , way , useless . You need buy new ones . And 's money . - Houston , wir haben ein problem ! # BitcoinCrash # Buy Bitcoin
#
#
# Tweet ID: 1247807
# Text: According experts , reason market crash io inflation USFD rate hike . I 'm wondering crypto market goes & amp ; . Any logic behind # BitcoinCrash # Bitcoin
#
#
# Tweet ID: 1248593
# Text: All previous slumps people said `` Just look bitcoin log graph ! '' Well breaking line mean ? # Cryptocrash # Bitcoin # BitcoinCrash # BitcoinFinancialCrisis # CryptoFinancialCrisis https : //t.co/1bvAv9Q9M8
#
#
# Tweet ID: 1249304
# Text: “ Obviously , expensive digital images monkeys going improve world immensely , ” # Gates said sarcastically # Crypto # Nft # Berkeley # BitcoinCrash # bitcoin https : //t.co/gRRyd6GZDx
#
#
# Tweet ID: 1249769
# Text: Nayib Bukele made worst financial decision purchased # Bitcoin using taxpayers ' money . # ElSalvador bleeding money : Losing 57 million dollars self proclaimed CEO El Salvador threatens `` buy dip '' # BitcoinCrash https : //t.co/u9tlnz511L
#
#
# Tweet ID: 1249844
# Text: I hope 'm wrong think next stage Bitcoin 200K . Retweet agree . $ BTC # BitcoinCrash # BTC # CryptoMarket # Cryptos # cryptocurrency
#
#
# Tweet ID: 1250107
# Text: Are long Crypto ? @ business # Bitcoin # Crypto # inflation # Fed # Cryptos # Cryptocrash # BitcoinCrash # cryptocurrency # CryptoMarket https : //t.co/w89S8iiGEH
#
#
# Tweet ID: 1250399
# Text: Gold miners past , bitcoin miners . # BitcoinCrash # gold # BTC
#
#
# Tweet ID: 1250686
# Text: I hate see people 's money disappear , I love see Crypto crashing . # BitcoinCrash # BTC https : //t.co/SlcuVr9Txo
#
#
# Tweet ID: 1250984
# Text: bullsh * bull traps Be careful , may get left behind . # cryptocurrency # BTC # BitcoinCrash
#
#
# Tweet ID: 1250990
# Text: A name never appropriate . # AllForOne . All # Crypto stuff one spot . @ uselesscrypto @ AppAllForOne # Useless # UselessCrypto # BitcoinCrash # BTC # Wednesdayfeeling # Wednesdayvibe https : //t.co/vE7a8AodaC
#
#
# Tweet ID: 1251066
# Text: Crypto hedge fund Three Arrows Capital faces potential insolvency # liquidated lenders . The liquidation totaled least $ 400 million . # Cryptocrash # CryptocurrencyNews # Crypto # bitcoins # BitcoinCrash # BTC # Ethereum # ETH # BNB # BinanceSmartChain # Binance BTC https : //t.co/izTma4Rp2l
#
#
# Tweet ID: 1251467
# Text: Celsius Network ( CEL ) onboarded restructuring lawyers Akin Gump Strauss Hauer & amp ; Feld find potential solutions firm 's financial woes . # Cryptocrash # CryptocurrencyNews # Crypto # BTC # BitcoinCrash # bitcoins 1 BTC # Ethereum # ETH # BNB # Binance # BinanceSmartChain
#
#
# Tweet ID: 1251560
# Text: Crypto fake 🥲🥲🥲 # BTC # BTCIM # crypto # CryptocurrencyNews # Ethereum # cryptocurrency # BitcoinCrash # cryptocurrencies # ETH
#
#
# Tweet ID: 1251943
# Text: `` We Wont Forget What We Have Learned From Our Past , From Its Lessons , The Future Is Forged . '' Official Page @ MekaRim_NFT Official Discord https : //t.co/7R24N1liTA # CryptocurrencyNews # BTC # BitcoinCrash # BITCOIN # artist # Metaverse # Metaverse_APP # artworks https : //t.co/DTTjleX9HE
#
#
# Tweet ID: 1254443
# Text: Okay GN # Bitcoin # BitcoinCrash . stochastically ... I hate 97 % . Like 's 2 standard deviations . I wo n't addle pretty little brains kurtosis , 's factor .
#
#
# Tweet ID: 1255615
# Text: @ saylor correct 1 $ BTC = 1 $ BTC . But $ 60k equal $ 20k . So logic idiotic # BuyBitcoin # BTC # Bitcoin # BitcoinCrash # CryptoMarket # FOMC # Powell https : //t.co/0GwX2RyFrE
#
#
# Tweet ID: 1255629
# Text: If looks like scam , plunges like scam makes poor like scam , ’ scam . # Bitcoin # bitcoins # BitcoinCrash # CryptoCrash # BitcoinScam # CryptoScam # CrapCurrencies https : //t.co/fnVztCPp57
#
#
# Tweet ID: 1257141
# Text: @ RiotBlockchain @ chadeverett @ JasonLes_ @ WhinstoneUS Are forcing community without consent & amp ; literally going get people killed stupid # Bitcoin `` mines '' GO AWAY ! # PonziCoins # ClimateCrisis # Cryptocrash # BitcoinCrash https : //t.co/pB0DysYVB7
#
#
# Tweet ID: 1258347
# Text: Extreme fear dominated bitcoin landscape month metric lowest position years https : //t.co/FocmO82aK0 By @ Crypto_Potato # Bitcoin # BTC # Cryptocrash # BitcoinCrash
#
#
# Tweet ID: 1259333
# Text: In hours , know crypto market continue crashing bounce due FOMC press conference : https : //t.co/kr38dPKzqp Stay tuned , could decisive 👀 # Bitcoin # BitcoinCrash # bearmarket # stockmarketcrash
#
#
# Tweet ID: 1259549
# Text: Our city council , econ dev board & amp ; county commissioners invited vampires house . Imagine basing projected tax revenue highly volatile , exploitative & amp ; destructive industry . @ RiotBlockchain @ JasonLes_ @ chadeverett # PonziCoins # BitcoinCrash # Bitcoin https : //t.co/q9Z2I1VcVF
#
#
# Tweet ID: 1259914
# Text: As I said earlier , I WAS # TrustWallet user I WAS # Metamask user . The @ AppAllForOne everything I need . @ uselesscrypto @ AppAllForOne # uselesscrytpo # useless # AllForOne # AppAllForOne # BTC # Bitcoin # BitcoinCrash # Crytpo https : //t.co/kgOtVgnkFH
#
#
# Tweet ID: 1259921
# Text: # Bitcoin weekly RSI lowest point EVER ! ! ! ! This time buy ! ! Of course go lower using trailing buy orders prevent missing train . # Crypto # Cryptocrash # Ethereum # altcoins # BTC # BitcoinCrash https : //t.co/TrKzuM8mtI
#
#
# Tweet ID: 1260280
# Text: The @ RevivalDeFi Dev Team look tough times tough times . They look opportunity work development grow ecosystem . # RVLx # RevivalDeFi # RevivalNFTs # BTC # Bitcoin # BitcoinCrash # wednesdaythought # WednesdayMotivation https : //t.co/fCGNgzUcL4
#
#
# Tweet ID: 1261015
# Text: # BTC bottomed . Dump harder ! # Bitcoin # BitcoinCrash https : //t.co/CtLGY9NWAq
#
#
# Tweet ID: 1261178
# Text: How people reluctant accept # Bitcoin bound enter bear market crazy me… . We ’ seen twice already everyone still acting surprised😏 # crypto # Bitcoin # BitcoinCrash
#
#
# Tweet ID: 1261449
# Text: Today looks like bull traps # BTC seeing way . BE CAREFUL . I 'm buying . # Crypto # stockmarketcrash # bearmarket # BitcoinCrash
#
#
# Tweet ID: 1261504
# Text: Is little left sell ? Despite drop days , since December 2018 less 10 % circulating # Bitcoin supply exchanges . # BitcoinCrash # Cryptocrash # CryptocurrencyNews # Cryptos
#
#
# Tweet ID: 1263045
# Text: # Bitcoin indicators update Daily 3D chart . - 3D RSI div broken - volatility remains relatively high - 3D MFI still giving bullish div - bears still control # Bitcoin # BitcoinCrash # BTC # crypto # ThothTradingZone https : //t.co/eFaTJbPQQj
#
#
# Tweet ID: 1263366
# Text: Hard Market This Week ...... cares ? ? ? ...... panic people get worst ...... End Of era Here ..... world knew longer .... Take leave . # Bitcoin # BitcoinCrash # Cryptocrash # CryptoMarket
#
#
# Tweet ID: 1265586
# Text: # Fed 75bps 🙏 # Cryptos # stocks falling invest afford loose global recession coming # BTC # NASDAQ # CryptocurrencyNews # Ethereum # altcoins # BitcoinCrash # AVAX # atom # sol # LUNA # ada # altcoins # stockmarketcrash $ btc # CelsiusNetwork $ route $ kda ust https : //t.co/cnvYrv6nnm
#
#
# Tweet ID: 1265611
# Text: # Bitcoin technical indicators point $ 10,000 . I feel badly people $ 30k - $ 65k . # BitcoinCrash https : //t.co/DeklJvuBX9
#
#
# Tweet ID: 1265727
# Text: @ CryptoWhale @ CryptoWhale mean Bitcoin reach $ 15,000 within month # BTC # Bitcoin # BitcoinCrash
#
#
# Tweet ID: 1266191
# Text: Bitcoin going crazy like 😯😯😯 # BitcoinCrash # Bitcoin https : //t.co/PdhwgijO3B
#
#
# Tweet ID: 1266277
# Text: Be careful guys . The fed announce spike interest rates happen . Prices likely tank even lower . Be careful . Catch live https : //t.co/ccCXxo4ZrR # BTC # bitcoin # BitcoinCrash # cryptocurrency # Etherum # ETH
#
#
# Tweet ID: 1266348
# Text: Amidst recession concerns , investors remain fearful . ( 3/3 ) # CryptoMarket # BitcoinCrash # recession # Coinbase # Ethereum # ETH # BTC # Bitcoin
#
#
# Tweet ID: 1267228
# Text: @ SBF_FTX Market held breath today ’ data , boom ! hit 75 bps coming soon ! , WHAT DOES MEAN CRYPTO ? & lt ; & gt ; Model suggests slide areas soon xchange blocks lifted # 18k # 14k # Cryptocrash # BitcoinCrash # Binance # Bitcoin # Ethereum
#
#
# Tweet ID: 1267385
# Text: Just months ago 2.1T market cap less 1 trillion , I 'm doubting ... 🤔 think crypto market coming end # Bitcoin # BitcoinCrash https : //t.co/jgczoxgoDS
#
#
# Tweet ID: 1267879
# Text: My portfolio switched green daily time frame . Will witness medium-sized squeeze upwards ? # Bitcoin # BitcoinCrash # Crypto
#
#
# Tweet ID: 1267888
# Text: Now I release say crypto currency weak Wake-up one morning seeing # BNB # BTC # ETH etc put someone wheelchair 😂🤣 # Binance # BinanceSmartChain # BitcoinCrash @ cz_binance https : //t.co/YbCVU0sApq
#
#
# Tweet ID: 1268303
# Text: # BillGates blasts # cryptocurrencies , # NFTs based 'greater-fool ' theory https : //t.co/c7MRoLOBaj “ Obviously , expensive digital images # monkeys going improve world immensely ” @ BillGates said sarcastically # BTC # BitcoinCrash # Bitcoin # Altcoins # Cryptocrash # Crypto
#
#
# Tweet ID: 1268695
# Text: BTCUSD IS DOWN -70 % FROM ATH ’ S # BTCUSD # btc # bearmarket # BitcoinCrash
#
#
# Tweet ID: 1268741
# Text: @ WatcherGuru 😂😂😂Big fish 🦈 want offload # Bitcoin small fry 🐟 . Sorry Michael , I 'll wait price €2,000 # BitcoinCrash
#
#
# Tweet ID: 1269224
# Text: # Bitcoin demand reacting price extremely . Given , think gon na reach $ 16K- $ 17K days range god knows happens . Take care . IGNORE : # BTC # Crypto $ BTC # ETH $ ETH # cryptocuurency # Cryptocrash # BitcoinCrash # ADA # FTM # Fantom # NFT https : //t.co/nK32mdwKVP
#
#
# Tweet ID: 1270288
# Text: Stay away Bitcoin . U.S. Fed raises interest rate 75 basis points , marking sharpest rate hike since 1994 . Another negative news dump Bitcoin $ 14,000 . Massive sellout next days . # Bitcoin # BTC # BitcoinCrash # Market # Finance # NEWS https : //t.co/YI15rIBTQL
#
#
# Tweet ID: 1270407
# Text: Benson angry still n't looked NFT collection # Etherum fallen . # BTC # BTCUSDT # NFTs # Regularshow # BitcoinCrash # NFTCommunity # NFTGiveaway https : //t.co/d1orVBgwls https : //t.co/iiQBjUid54
#
#
# Tweet ID: 1270581
# Text: Again Boring Sideways Momentum Started 😑 Bitcoin & amp ; Ethereum Chart | Update 1D & amp ; 4H |Question Mark Link👇 https : //t.co/PICL9AAqur # questionmark # bitcoin , # btc , # Crypto , # Cryptocrash , # Cryptos , # CryptoMarket , # Bitcoin , # bitcoins , # Etherum , # ETH # Michael Saylor # BitcoinCrash # bitcoin
#
#
# Tweet ID: 1270775
# Text: With bearish macro economics less people currently water comparing previous cycle bottoms , still room panic liquidation . # bitcoin # BitcoinCrash # Bitcoin # Cryptocrash https : //t.co/KI6WyEMjD0
#
#
# Tweet ID: 1271521
# Text: Let share 2 charts confort little hearts . # Bitcoin # BitcoinCrash We , 1458 average . Not financial advice 😜 https : //t.co/BoFCLx4H3J
#
#
# Tweet ID: 1272108
# Text: # Bitcoin closes previous day 's close second day row . # BitcoinCrash # Cryptocrash # fud
#
#
# Tweet ID: 1273133
# Text: Bitcoin liquidation expected next day arround 389,521 bitcoins liquidated . That amount follow liquidation # SouthKorea # Japan # HongKong Expect price drop £9,800 GBP # Finance # cryptocurrency # Bitcoin # Liquidation # BTC # Markets # BitcoinCrash https : //t.co/YuVI99MYQB
#
#
# Tweet ID: 1276058
# Text: # Bitcoin heavy manipulated trigger margin calls . # BitcoinCrash # bitcoinprice
#
#
# Tweet ID: 1276959
# Text: Crypto like Bitcoin supposed decentralized . It 's anything decentralized . It 's tied US stock market via crypto funds US inflation . Furthermore , pyramid schemes illegal US . @ FTC # DeFi @ CeFi # Crypto # Bitcoin # BitcoinCrash # PyramidScheme https : //t.co/TTiuKb9qBI
#
#
# Tweet ID: 1277339
# Text: If # Bitcoin dips level , could game # cryptocurrency . And ’ $ 87 away point . https : //t.co/KlONbjA6d9 via @ newscomauHQ # BitcoinCrash # cryptocurrencies
#
#
# Tweet ID: 1277841
# Text: # Cryptocrash # BitcoinCrash # bitcoin # BTC Market unpredictable today , thoughts $ BTC : https : //t.co/wkElmCyHEW
#
#
# Tweet ID: 1278260
# Text: Done crypto shit . # Cryptocrash # bearmarket # Cryptocrash # BTC # CryptoMarket # BitcoinCrash # Bitcoin # 1ETH still 1 $ ETH # 1BTC still 1 $ BTC https : //t.co/4tqqwDzJdW
#
#
# Tweet ID: 1278352
# Text: Psychology turned negative $ TSLA $ QQQ # Bitcoin # ETH $ AMZN $ GME $ AMC $ META $ GOOGL $ NFLX # inflation # Cryptos # stocks # BTC # NASDAQ $ SPY # Ethereum # altcoins # BitcoinCrash # AVAX # atom # sol # LUNA # ada # altcoins # stockmarketcrash $ btc $ sol $ eth https : //t.co/RFrRpja3qz
#
#
# Tweet ID: 1278396
# Text: Green red today ? $ BTC # BTC # Bitcoin # Bitcoin2022 # BitcoinCrash
#
#
# Tweet ID: 1278966
# Text: The trading activity Bitcoin commodity futures Binance platform hit $ 33,571,077,689.27 previous 24 hours # cryptoding # cryptocurrency # crypto # bitcoin # btc # Cryptocrash # BitcoinCrash # Binance # bitcoinnews # CryptoNews https : //t.co/VWtWFrXInB
#
#
# Tweet ID: 1278997
# Text: Traditional markets may correct another 20-25 % find bottom . And could mean approx 40-50 % drop # BTC prices . Save tweet refer Q4 2022 . # Nifty # NASDAQ # SP500 # stockmarkets # BitcoinCrash # Bitcoin2022 # cryptocurrency
#
#
# Tweet ID: 1279826
# Text: Look like 's global recession time worst yet come brace impact # inflation # Cryptos # stocks # BTC # NASDAQ $ SPY $ AMC # Ethereum # altcoins # BitcoinCrash # AVAX # atom # sol # LUNA # ada # altcoins # stockmarketcrash $ btc $ sol $ kda $ eth https : //t.co/Wt7L1c6XSd
#
#
# Tweet ID: 1280183
# Text: You think crypto ally ? But merely adopted crash . I born , molded . # Web3 # BTC # ETH # Crypto # Cryptocrash # CryptoMarket # BitcoinCrash https : //t.co/zXobsnbp2c
#
#
# Tweet ID: 1282698
# Text: Uh Oh # Crypto Bro : Elon Musk sued $ 258B alleged # Dogecoin pyramid scheme https : //t.co/8XPhu8Q21P # ElonMusk # Musk # Tesla # SpaceX # Twitter # Elon # TSLA # DOGE # TWTR $ TWTR $ TSLA $ DOGE # cryptocurrency # cryptocurrencies # CryptoNews # Cryptocrash # BTC # Bitcoin $ BTC # BitcoinCrash
#
#
# Tweet ID: 1283810
# Text: Means # Altcoins still drop another -90 % become shitcoin like luna brace self worst yet come # inflation # Cryptos # stocks # BTC # NASDAQ $ SPY $ AMC # Ethereum # BitcoinCrash # AVAX # atom # sol # LUNA # ada # altcoins # stockmarketcrash $ btc $ sol $ kda $ eth https : //t.co/cjzj0tRFjY
#
#
# Tweet ID: 1288481
# Text: $ BTC trying use previous time high resistance support , bullish bounce area . RSI also extremely oversold area ! bounce send us 28,116-41,879-69,404 # BTC # BTCUSDT # Bitcoin # bitcoins # BitcoinCrash # cryptocurrency https : //t.co/T5yJeGYxlP
#
#
# Tweet ID: 1289770
# Text: # Russia 's third-largest oil producer , # Gazpromneft , entering # bitcoin mining space Gazpromneft partnering # Swiss-based # bitcoinmining firm BitRiver # Crypto # BTC # CryptoNews # bitriver # blockchains # BitcoinCrash
#
#
# Tweet ID: 1289771
# Text: Does anyone remember liquidity test last year ? Stay away Bitcoin next hours big red candle $ 1.5 billion liquidations . Price drop $ 14,200 Be careful # Bitcoin # BTC # Liquidation # Cryptocrash # BitcoinCrash https : //t.co/PnQF9x58GH
#
#
# Tweet ID: 1295366
# Text: Every time feel miserable remember people `` predicting '' # BTC 100K 2020 , 2021 2022 . Because n't like reality , always make bullshit long show convinced people follow blindly . # BitcoinCrash
#
#
# ==================================================
#
# Hashtag: bearmarket
# Number of associated tweets: 129
#
# Hashtag: bearmarket
#
# Tweet ID: 1205059
# Text: How ’ guy took one $ BTC @ TomBrady ‘ 600th TD ball feeling ? $ BTC $ 22k holding half million gross sale . # btc # crash # Cryptocrash # bearmarket
#
#
# Tweet ID: 1205347
# Text: @ 618_cowboy work rate unrivalled 🔥If subscribed already , high quality content including tutorials improve chart game also date TA lifeline # bearmarket # btc # Crypto # trading https : //t.co/w9I21AHe8N
#
#
# Tweet ID: 1205784
# Text: Folks believe 've bottomed , hence selling # BTC buy # Altcoins Now , Alts pumping , thus making # BTC unstable . Yesterday dump crazy , plus massive short market ; market wo n't stable FOMC tomorrow # Bitcoin # bearmarket # altcoins https : //t.co/LxS11ovGZA
#
#
# Tweet ID: 1208076
# Text: Winter coming crypto , make calls carefully . # Cryptocrash # Cryptos # CryptocurrencyNews # BTC # altcoin # bearmarket
#
#
# Tweet ID: 1208115
# Text: @ binance withdrawals seem back track working well moment . Small hardware issues caused issues earlier fixed believe issue would reoccur . # btc # eth # bitcoin # trading # Cryptocrash # cryptotrading # altcoin # bearmarket
#
#
# Tweet ID: 1208226
# Text: Update BTC : expecting bullishness month , still bearish rest year though . When exchanges start go bankrupt game . # btc # bearmarket https : //t.co/lROeXDun0k https : //t.co/hoD2ivngqQ
#
#
# Tweet ID: 1208306
# Text: The lower prices go , louder bears get . The louder bears , lower price go . It seems history always repeats one way another ... Excitement replaced anger keep building . 💪 # tax # crypto # BTC # ETH # news # bearmarket
#
#
# Tweet ID: 1208459
# Text: The CEO Devere Group , Nigel Green , projected bullish run bitcoin ’ price Q4 year , citing recent market collapse nearing end . # BTC # NASDAQ # StockMarket # Cryptocrash # bullrun # bearmarket # crypto # Binance # Ethereum # mercuricapital # altcoins https : //t.co/UgHsMiWItJ
#
#
# Tweet ID: 1208652
# Text: This long time close btc 30k $ told us thing worse coming butt .... much worse . Now $ btc # BTC # Bitcoin # BNBUSDT # Ethereum $ bnb $ Btc # eth # crypto # Cryptocrash # bearmarket https : //t.co/m9YjbxwVLg
#
#
# Tweet ID: 1208800
# Text: Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR https : //t.co/e0CZmUZVlh
#
#
# Tweet ID: 1208804
# Text: Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR https : //t.co/8VGEeuK0bB
#
#
# Tweet ID: 1208824
# Text: Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR https : //t.co/nGySiPPDr4
#
#
# Tweet ID: 1208837
# Text: Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR https : //t.co/ncf5A8wnuQ
#
#
# Tweet ID: 1208841
# Text: Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR https : //t.co/tvGA0Mjehu
#
#
# Tweet ID: 1208858
# Text: Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR # orion https : //t.co/E4AX2Lh0Qc
#
#
# Tweet ID: 1208867
# Text: Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR https : //t.co/kYwPWlH7Wy
#
#
# Tweet ID: 1208882
# Text: Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR https : //t.co/cGXGhKnw83
#
#
# Tweet ID: 1208892
# Text: Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR https : //t.co/4kHb43spn7
#
#
# Tweet ID: 1208902
# Text: Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR https : //t.co/lymaeLF9r6
#
#
# Tweet ID: 1208920
# Text: Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR https : //t.co/wfOnqhKnUI
#
#
# Tweet ID: 1209004
# Text: Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR https : //t.co/Rxrx893V47
#
#
# Tweet ID: 1209145
# Text: Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR https : //t.co/gSCrO5pstZ
#
#
# Tweet ID: 1209260
# Text: @ XcademyOfficial Game changing # creatoreconomy # creatortoken # XCAD # watch2earn . Only one thing I still .. Accumulate $ XCAD .. Bull bear market $ AXS $ VRA $ THETA $ CHZ $ GMT @ mcontent_ # bearmarket # thebull # NASDAQ # bloomberg # digitaljournal # btc # bnb # HBAR https : //t.co/292Buvuc1N
#
#
# Tweet ID: 1209808
# Text: Having difficulties blowing capital dip case dump crying case pump I lot fiat left😕 # btc # bearmarket # BITCOIN # Ethereum # bnb # SOL # ATOM $ WOO # NEAR # AVAX
#
#
# Tweet ID: 1211101
# Text: People afraid I ca n't wait masses become truly bored crypto NFTs . I 'll , lurking shadows , waiting snatch cheap coins jpegs . # SOL # SolanaNFTs # BTC # bearmarket
#
#
# Tweet ID: 1212088
# Text: U wait buy market recovers buy dips , 've market long enough u know ..... # eth # atom # tlos # bearmarket # eos # hex # btc # egld # dripnetwork # ape # bnb
#
#
# Tweet ID: 1213684
# Text: I hope 200 weekly moving average holds $ BTC might wick lower everyone looking lose ’ really bad news # crypto # crytocurrency # BTC # bitcoin # ETH # ethereum # cryptocrash # crash # bearmarket
#
#
# Tweet ID: 1214222
# Text: This gon na first # bearmarket already # REKT 🙃 # btc # poor # Ethereum
#
#
# Tweet ID: 1214856
# Text: 's gon na tough boys 🥴 # bearmarket # Cryptos # BTC # Ethereum # ETH # Cryptocrash # NFTs https : //t.co/ozbdmLvGSV
#
#
# Tweet ID: 1215401
# Text: With shit happening world 🌎 due centralization , recent # celciusnetwork centralized # DeFi fiasco , really need reiterate importance # Decentralization $ CCX # bearmarket # BTC
#
#
# Tweet ID: 1215634
# Text: Why # markets collapse yesterday ? 📉 🐻 🔻 # BTC dropped $ 23K , lowest level since Dec2020 ( current price : $ 22.1K @ coingecko ) 🔻 @ CelsiusNetwork paused withdrawals , exchanges , & amp ; transfers accounts “ due extreme market conditions ” # bearmarket # Cryptocrash
#
#
# Tweet ID: 1216880
# Text: 2019/2020 # bearmarket analysis single chart # Bitcoin # charts https : //t.co/WIkLBAO7lG
#
#
# Tweet ID: 1217006
# Text: @ ShibInform This shit dose make want keep coins . Be useful show resistance lev , support levs target levs slide fuck feed . # SHIBARMY # Ethereum # shib # cryptocurrency # altcoins # bearmarket # BTC ETH # buythedip # Bullish
#
#
# Tweet ID: 1217213
# Text: @ MicroStrategy CEO @ saylor suggested firm sell $ BTC . # cryptocurrency # Crypto # BTC # ETH # Metaverse # Web3 # NFTCommunity # NFTs # NFTGiveaway # saylor # algorand # bearmarket
#
#
# Tweet ID: 1217615
# Text: Hidden 🐻 divergence 1H shorting $ btc towards purple line . Looking range purple lines . Tbf I chose wrong direction ( long ) first… # bearmarket # BTC # cryptocurrencies # Cryptocrash https : //t.co/I1JQjoJlg9
#
#
# Tweet ID: 1218244
# Text: If 6 months prices going people start calling current situation # bearmarket waiting another 80-90 % drop I doubt price going start going like crazy # btc $ btc $ eth $ deero $ vra $ trias $ luna
#
#
# Tweet ID: 1221889
# Text: # Bitcoin closed 8 daily red candles . Let 's hope 9th daily candle green . # bearmarket https : //t.co/IZnqHQViL5
#
#
# Tweet ID: 1222633
# Text: Unfortunately I 've got # Bitcoin target $ 11,200 monthly chart . I usually n't go past daily chart futures , equities crypto , since # bearmarket I 'm trying gage might land . This advice . # cryptotrading # cryptoartist
#
#
# Tweet ID: 1223093
# Text: @ Diditaihuttu After 18k 14k , fall 8k . Hard pill swallow truth . # BTC # bearmarket
#
#
# Tweet ID: 1224371
# Text: Convenience choice situation crypto gurus . Highlight correct ones brush wrong calls rug . # btc # eth # bearmarket # wheresthebottom # cryptocrash
#
#
# Tweet ID: 1225619
# Text: @ HydroWhalesClub 🚀always # BTC # BTCmining ( # hydroelectric ) ⚡️ , always growing ( # Compounding # investing ) 🚀gave back ocean 🐳🌎 🚀 # bullmarket # bearmarket always green 💰🪙💵 🚀 # doxxedteam 👨‍👨‍👧‍👧 🚀1st ever # legalaudit 🧑‍⚖️⚖️for # NFTs 🖼️🐳 🚀only 9,999 🐳 ever 🚀 https : //t.co/UXnGdSUcrF
#
#
# Tweet ID: 1226007
# Text: Asking friend , '' If someone hunt liquidation , isnt mean wants bag cheaper price ? '' # Ethereum # BTC # bearmarket
#
#
# Tweet ID: 1226410
# Text: # Binance Reveals Incident That Forced It Freeze # BTC Withdrawals https : //t.co/ad2FnNsKc8 # Cryptocrash # stockmarketcrash # bearmarket # BitcoinCrash # Cryptos # NFTCommmunity
#
#
# Tweet ID: 1227512
# Text: The past days # Crypto : - https : //t.co/Gmht1EBbiL laying 250 - Blockfi laying 170 - Coinbase laid 1100 - # BTC nearly 30 % 7 days billions liquidations - Celsius meltdown # ouch # bearmarket # hodl # cryptonews # cryptoupdates
#
#
# Tweet ID: 1228170
# Text: Coinmarkrtcap stop showing total market cap crypto market ! ! ! What mean ? ? ? # bearmarket # Bitcoin # Ethereum
#
#
# Tweet ID: 1228625
# Text: @ Aggroed001 99 % crypto projects fail . That 's I n't sleep lot days 🚀 Some serious Altcoin deals rn ... invest wait ! ? # Bitcoin # bearmarket
#
#
# Tweet ID: 1228997
# Text: It ’ going cold cold summer ! ! ! # cryptowinter # bearmarket # crypto # wolfpacofcrypto # btc
#
#
# Tweet ID: 1231282
# ...
#
#
# Tweet ID: 1226829
# Text: Anytime 2 year yield rises 10 year yield , 's followed recession .. per image 2 , see went negative back April ... # economics # recession # stockmarketcrash # stocks # bitcoin # crypto https : //t.co/yA47CHs4xW
#
#
# Tweet ID: 1230496
# Text: GM Volatility shock : ( GMT +2 ) -14:30 ( main retail ) -15:30 ( open U.S ) -16:30 ( oil stocks ) -20:00 ( FOMC projection + interest rate ) — & gt ; main event day . -20:30 ( conference FOMC ) Be careful today . # stockmarketcrash # StockMarket # crypto # Cryptocrash # BTC https : //t.co/FA6OLSXGkO
#
#
# Tweet ID: 1230963
# Text: Even creepy Joe telling people 's huge opportunity knock markets .... I would n't quite sell house car Buy Bitcoin like @ rovercrc @ MMCrypto yet🙃 # BTC # stockmarketcrash https : //t.co/AlGjv2Of85
#
#
# Tweet ID: 1232165
# Text: So rough day today June 15 predicted @ BuyCryptoAI . I stay market I 100 % stablecoins . And ? # bitcoin # NFT # blockchain # BTC # AI # money # Crypto # ArtificialIntelligence # NASDAQ # trading # stockmarketcrash # StableCoin
#
#
# Tweet ID: 1232428
# Text: # StETH Loses Peg To # ETH ! Can This Affect The Price Of # Ethereum ? Click link read complete article Kanishk 👇 https : //t.co/2DqvfgEZqZ # Solana # btc # LUNA # NFTs # Nifty $ XRD $ OCI # Cryptocrash # SGXNIFTY # stockmarketcrash # CryptoMarket https : //t.co/NCq3XPLY9u
#
#
# Tweet ID: 1232443
# Text: Great opportunity buy . Be greedy others fearful , fearful others greedy . - Warren Buffett # Bitcoin # stockmarketcrash # Cryptocrash
#
#
# Tweet ID: 1232846
# Text: 🚨we close pessimistic scenario yet PA signs rock solid bottom 🤷‍♂️ loose previous ATH 19 891 # btcusd eventually say “ hi ” sub 10k # BTC prices # Cryptocrash # itaintover # morepaintocome # stockmarketcrash https : //t.co/Y4ZkgwLBND
#
#
# Tweet ID: 1236658
# Text: We told morning switch stablecoin . And would tough day . @ BuyCryptoAI right . # bitcoin # NFT # blockchain # BTC # AI # money # Crypto # ArtificialIntelligence # NASDAQ # trading # stockmarketcrash # StableCoin https : //t.co/HEFYM9xKAl
#
#
# Tweet ID: 1241175
# Text: Bitcoin gold global stock market crude oil $ btc # stockmarketcrash # Bitcoin
#
#
# Tweet ID: 1243812
# Text: Looks Like Btc actually hit 20k sad year🥺 # btc # bitcoin # 100xcoin # 100x # gem # gems # eth # ethereum # luna # apecoin # tifi # crypto # Cryptocrash # stockmarketcrash # AMC # Celsius # 100xgem
#
#
# Tweet ID: 1249115
# Text: This S & amp ; P 500 's worst start year since 1962 , according Goldman Sachs 🤡🌍 # wgmi # stockmarketcrash # bitcoin
#
#
# Tweet ID: 1252851
# Text: The bottom # crypto long way . What happens impending # stockmarketcrash takes publicly traded # Bitcoin mining companies ' . Who 's going save ? They dump coins onto # market . https : //t.co/ng5F7mn1gt https : //t.co/VUv0vJSRGD
#
#
# Tweet ID: 1257148
# Text: So .... Fed raise interest rates 0.75 % — biggest single increase 28 years . What going mean # StockMarket # crypto ? ( Since crypto highly correlated stocks , 's basically question . ) # bitcoin # stockmarketcrash https : //t.co/hrVwMP4XKA
#
#
# Tweet ID: 1257621
# Text: What Caused The Crypto Crash ? | Is Crypto Dead ? | How Can You Handle It ? https : //t.co/oXYXjox1aR # investment # invest # ethereum # bitcoin # eth # btc # cryptocurrency # crypto # stockmarketcrash # StockMarket # stocks # Cryptocrash # Crypto
#
#
# Tweet ID: 1258084
# Text: # Fed Expected Announce # InterestRate Hike Slow Down # Inflation Read More👉https : //t.co/eGdZPAwhA6 # recession2022 # economy # FederalReserve # Bitcoin # Cryptocrash # 1btc # chinalockdown # UkraineRussianWar # stockmarketcrash https : //t.co/OQ9hlOZNc6
#
#
# Tweet ID: 1258546
# Text: At least China FUD summer . # Bitcoin # Crypto # stockmarketcrash # Cryptocrash # China # FUD
#
#
# Tweet ID: 1259333
# Text: In hours , know crypto market continue crashing bounce due FOMC press conference : https : //t.co/kr38dPKzqp Stay tuned , could decisive 👀 # Bitcoin # BitcoinCrash # bearmarket # stockmarketcrash
#
#
# Tweet ID: 1261449
# Text: Today looks like bull traps # BTC seeing way . BE CAREFUL . I 'm buying . # Crypto # stockmarketcrash # bearmarket # BitcoinCrash
#
#
# Tweet ID: 1262256
# Text: The Fed never far behind curve 🤔 . Not Fed create mess , way behind curve fixing . The ultimate fix : Fed rate hike 400 BPs , let stock market collapse hit reset button. # BTC # bearmarket # Crypto # stockmarketcrash
#
#
# Tweet ID: 1262704
# Text: Most countries shall Japan : save bond market sacrify currency market , would painful less painful complete reset markets would catastrophic 1929 crisis . # BTC # stockmarketcrash # bearmarket
#
#
# Tweet ID: 1262832
# Text: Bitcoin Fear Greed Index 7 - Extreme Fear Current price : $ 20,970 . # BTC # bearmarket # stockmarketcrash # Crypto # NFTCommunity
#
#
# Tweet ID: 1262870
# Text: Fed Chairman taking back access liquidity market ... Investors crying ! ! ! 😀😀 # FOMC # StockMarket # NASDAQ # Bitcoin # stockmarketcrash https : //t.co/hchxy8PuJE
#
#
# Tweet ID: 1265586
# Text: # Fed 75bps 🙏 # Cryptos # stocks falling invest afford loose global recession coming # BTC # NASDAQ # CryptocurrencyNews # Ethereum # altcoins # BitcoinCrash # AVAX # atom # sol # LUNA # ada # altcoins # stockmarketcrash $ btc # CelsiusNetwork $ route $ kda ust https : //t.co/cnvYrv6nnm
#
#
# Tweet ID: 1270337
# Text: Hammer time market close . Stonks getting ready fade fake FOMC pump . Bitcoin crypto follows move later today . RIP # stockmarketcrash # Bitcoin # Crypto
#
#
# Tweet ID: 1276971
# Text: GM GN I woke cause trouble . 👀 # Bitcoin # Cryptocrash # ETH # stockmarketcrash
#
#
# Tweet ID: 1278352
# Text: Psychology turned negative $ TSLA $ QQQ # Bitcoin # ETH $ AMZN $ GME $ AMC $ META $ GOOGL $ NFLX # inflation # Cryptos # stocks # BTC # NASDAQ $ SPY # Ethereum # altcoins # BitcoinCrash # AVAX # atom # sol # LUNA # ada # altcoins # stockmarketcrash $ btc $ sol $ eth https : //t.co/RFrRpja3qz
#
#
# Tweet ID: 1279826
# Text: Look like 's global recession time worst yet come brace impact # inflation # Cryptos # stocks # BTC # NASDAQ $ SPY $ AMC # Ethereum # altcoins # BitcoinCrash # AVAX # atom # sol # LUNA # ada # altcoins # stockmarketcrash $ btc $ sol $ kda $ eth https : //t.co/Wt7L1c6XSd
#
#
# Tweet ID: 1283810
# Text: Means # Altcoins still drop another -90 % become shitcoin like luna brace self worst yet come # inflation # Cryptos # stocks # BTC # NASDAQ $ SPY $ AMC # Ethereum # BitcoinCrash # AVAX # atom # sol # LUNA # ada # altcoins # stockmarketcrash $ btc $ sol $ kda $ eth https : //t.co/cjzj0tRFjY
#
#
# Tweet ID: 1287298
# Text: Crude 4 % power accurate analysis 🤞💪👇 . # investing # trading # forex # money # investment # finance # cryptotrading # BTC # StockMarket # stockmarketcrash https : //t.co/nQRUgpgvzx
#
#
# Tweet ID: 1289774
# Text: * Not investing advice * Every week I take $ 100 put work Future ME . This week 's picks : $ Coin - $ 50.25 $ Pltr - $ 8.08 x2= $ 16.16 # BTC - $ 33 It 's slow walk Mountain ⛰️ I 'm 🚶🏿‍♂️ # 1sat # recession # stockmarketcrash # future # invest # 1stepatatime # Crypto
#
#
# ==================================================
#
# Hashtag: Bollinger
# Number of associated tweets: 33
#
# Hashtag: Bollinger
#
# Tweet ID: 1206655
# Text: Pairs : ETHUSDT BUY:1198.87000 Time :6/14/2022 4:06:36 PM Average Decision : 55.84447FifteenMinutes Estimated Direction : UP # BTC # AXSBTC # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 4:07:01 PM
#
#
# Tweet ID: 1208925
# Text: Pairs : BTCUSDT BUY:22414.27000 Time :6/14/2022 5:48:02 PM Average Decision : 55.19492FifteenMinutes Estimated Direction : UP # BTC # POLYBUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 5:48:18 PM
#
#
# Tweet ID: 1212792
# Text: Pairs : BTCUSDT SELL:22409.50000 Time :6/14/2022 8:51:01 PM Average Decision:49.23682 FifteenMinutes Estimated Direction : DOWN # BTC # LAZIOEUR # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 8:51:35 PM
#
#
# Tweet ID: 1213274
# Text: Pairs : BTCUSDT BUY:22483.38000 Time :6/14/2022 9:21:28 PM Average Decision : 58.81123FifteenMinutes Estimated Direction : UP # BTC # ETHTUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 9:21:38 PM
#
#
# Tweet ID: 1213648
# Text: Pairs : BTCUSDT SELL:22402.15000 Time :6/14/2022 9:46:49 PM Average Decision:48.63719 FifteenMinutes Estimated Direction : DOWN # BTC # BATTUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 9:47:11 PM
#
#
# Tweet ID: 1214159
# Text: Pairs : ETHUSDT SELL:1203.22000 Time :6/14/2022 10:12:24 PM Average Decision:43.58995 FifteenMinutes Estimated Direction : DOWN # BTC # FILUSDT # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 10:12:43 PM
#
#
# Tweet ID: 1214704
# Text: Pairs : ETHUSDT BUY:1204.69000 Time :6/14/2022 10:38:27 PM Average Decision : 51.54037FifteenMinutes Estimated Direction : UP # BTC # OOKIETH # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 10:38:47 PM
#
#
# Tweet ID: 1215600
# Text: Pairs : ETHUSDT SELL:1182.00000 Time :6/14/2022 11:31:05 PM Average Decision:37.14705 FifteenMinutes Estimated Direction : DOWN # BTC # EOSTUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 11:31:26 PM
#
#
# Tweet ID: 1220527
# Text: Pairs : ETHUSDT BUY:1184.54000 Time :6/15/2022 2:19:28 AM Average Decision : 51.92900FifteenMinutes Estimated Direction : UP # BTC # RUNEBTC # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 2:19:56 AM
#
#
# Tweet ID: 1221339
# Text: Pairs : BTCUSDT BUY:22184.31000 Time :6/15/2022 2:49:13 AM Average Decision : 57.31320FifteenMinutes Estimated Direction : UP # BTC # STRATETH # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 2:49:59 AM
#
#
# Tweet ID: 1226416
# Text: Pairs : BTCUSDT SELL:21901.94000 Time :6/15/2022 5:49:02 AM Average Decision:48.04819 FifteenMinutes Estimated Direction : DOWN # BTC # BURGERBNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 5:49:27 AM
#
#
# Tweet ID: 1227781
# Text: Pairs : ETHUSDT SELL:1180.58000 Time :6/15/2022 6:43:48 AM Average Decision:36.82054 FifteenMinutes Estimated Direction : DOWN # BTC # GALABNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 6:44:02 AM
#
#
# Tweet ID: 1246915
# Text: Pairs : BTCUSDT BUY:21096.99000 Time :6/15/2022 2:42:08 PM Average Decision : 56.35327FifteenMinutes Estimated Direction : UP # BTC # TNTETH # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 2:42:29 PM
#
#
# Tweet ID: 1248488
# Text: Pairs : ETHUSDT BUY:1140.79000 Time :6/15/2022 3:16:09 PM Average Decision : 71.69082FifteenMinutes Estimated Direction : UP # BTC # REPBUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 3:16:33 PM
#
#
# Tweet ID: 1255099
# Text: Pairs : ETHUSDT SELL:1116.56000 Time :6/15/2022 5:33:35 PM Average Decision:46.94871 FifteenMinutes Estimated Direction : DOWN # BTC # OGBTC # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 5:33:52 PM
#
#
# Tweet ID: 1261055
# Text: Pairs : BTCUSDT SELL:20845.92000 Time :6/15/2022 7:43:06 PM Average Decision:19.52138 FifteenMinutes Estimated Direction : DOWN # BTC # ZENBTC # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 7:44:06 PM
#
#
# Tweet ID: 1278555
# Text: Pairs : BTCUSDT BUY:20897.27000 Time :6/17/2022 8:37:22 AM Average Decision : 55.49990FifteenMinutes Estimated Direction : UP # BTC # TRXAUD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 8:39:33 AM
#
#
# Tweet ID: 1278568
# Text: Pairs : ETHUSDT BUY:1106.18000 Time :6/17/2022 8:37:27 AM Average Decision : 53.97468FifteenMinutes Estimated Direction : UP # BTC # CAKEGBP # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 8:40:03 AM
#
#
# Tweet ID: 1278913
# Text: Pairs : BTCUSDT SELL:20720.00000 Time :6/17/2022 9:08:24 AM Average Decision:46.62709 FifteenMinutes Estimated Direction : DOWN # BTC # ENJBTC # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 9:08:37 AM
#
#
# Tweet ID: 1279315
# Text: Pairs : BTCUSDT BUY:20821.53000 Time :6/17/2022 9:38:59 AM Average Decision : 51.91310FifteenMinutes Estimated Direction : UP # BTC # WAVESPAX # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 9:39:09 AM
#
#
# Tweet ID: 1280658
# Text: Pairs : ETHUSDT BUY:1101.76000 Time :6/17/2022 11:09:59 AM Average Decision : 51.77895FifteenMinutes Estimated Direction : UP # BTC # XRPBUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 11:10:21 AM
#
#
# Tweet ID: 1281693
# Text: Pairs : ETHUSDT BUY:1100.97000 Time :6/17/2022 12:12:51 PM Average Decision : 51.06468FifteenMinutes Estimated Direction : UP # BTC # THETAUSDT # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 12:14:59 PM
#
#
# Tweet ID: 1282132
# Text: Pairs : ETHUSDT SELL:1089.18000 Time :6/17/2022 12:43:11 PM Average Decision:35.57898 FifteenMinutes Estimated Direction : DOWN # BTC # ENJEUR # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 12:43:32 PM
#
#
# Tweet ID: 1282670
# Text: Pairs : BTCUSDT BUY:20951.52000 Time :6/17/2022 1:15:17 PM Average Decision : 50.03904FifteenMinutes Estimated Direction : UP # BTC # NANOBNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 1:15:35 PM
#
#
# Tweet ID: 1283658
# Text: Pairs : ETHUSDT BUY:1105.31000 Time :6/17/2022 2:15:52 PM Average Decision : 54.63629FifteenMinutes Estimated Direction : UP # BTC # LINKAUD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 2:16:10 PM
#
#
# Tweet ID: 1284661
# Text: Pairs : ETHUSDT SELL:1095.33000 Time :6/17/2022 3:14:57 PM Average Decision:40.08177 FifteenMinutes Estimated Direction : DOWN # BTC # ETHPAX # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 3:15:18 PM
#
#
# Tweet ID: 1286437
# Text: Pairs : ETHUSDT BUY:1091.59000 Time :6/17/2022 4:40:56 PM Average Decision : 51.63476FifteenMinutes Estimated Direction : UP # BTC # RLCBNB # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 4:43:57 PM
#
#
# Tweet ID: 1293412
# Text: Pairs : BTCUSDT BUY:20676.34000 Time :6/17/2022 11:30:08 PM Average Decision : 50.95566FifteenMinutes Estimated Direction : UP # BTC # REIUSDT # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 11:34:39 PM
#
#
# Tweet ID: 1293738
# Text: Pairs : BTCUSDT SELL:20645.09000 Time :6/17/2022 11:59:37 PM Average Decision:47.11825 FifteenMinutes Estimated Direction : DOWN # BTC # TFUELPAX # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 12:00:12 AM
#
#
# Tweet ID: 1294516
# Text: Pairs : ETHUSDT SELL:1082.37000 Time :6/18/2022 12:58:52 AM Average Decision:44.79979 FifteenMinutes Estimated Direction : DOWN # BTC # OMBUSD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 12:59:20 AM
#
#
# Tweet ID: 1295150
# Text: Pairs : ETHUSDT BUY:1084.39000 Time :6/18/2022 1:58:20 AM Average Decision : 53.89582FifteenMinutes Estimated Direction : UP # BTC # VGXBTC # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 1:58:25 AM
#
#
# Tweet ID: 1295472
# Text: Pairs : BTCUSDT BUY:20530.00000 Time :6/18/2022 2:28:28 AM Average Decision : 51.53315FifteenMinutes Estimated Direction : UP # BTC # LUNAAUD # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 2:29:00 AM
#
#
# Tweet ID: 1295755
# Text: Pairs : BTCUSDT SELL:20458.65000 Time :6/18/2022 2:57:18 AM Average Decision:39.27997 FifteenMinutes Estimated Direction : DOWN # BTC # BETAUSDT # Bitcoin # RSİ # Bollinger -It investment advice . You visit profile alarms . YTD . 2:57:35 AM
#
#
# ==================================================
